# %% [markdown]
# # benchmark structural regression

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import matplotlib.ticker as ticker
import sys
from math import *

# %%
from utils_benchmark import * 
#test()

# %%
evaluation_dir = "/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/"
outdir = "../../../data/structural_regression/plots/02_benchmarkCPU/"

# %% [markdown]
# ## families infos

# %%
#### Load datasets informations (Homfam + extHomfam)
summary_homfam_exthomfam = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/01_summary_homfam_exthomfam.csv")
summary_homfam_exthomfam = summary_homfam_exthomfam.rename(columns={"dataset": "benchmarking_dataset"})

# %% [markdown]
# ## AF2 infos

# %%
# Load AF2 scores
af2 = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/02_summary_af2.csv")
af2_grouped = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/03_summary_af2_grouped.csv")

# %% [markdown]
# ## running time

# %%
def extract_all_traces(dataset):
    # ---------- EXTRACT SEQUENCES ---------------
    #traces_extracted_sequences_homfam = get_computation_times(join(evaluation_dir, dataset), dataset, "seqs_extracted")
    # ---------- AF2 PREDICTIONS -------------------------
    # traces_af2_homfam = get_computation_times(join(evaluation_dir, dataset), dataset, "structures/colabfold")
    # ---------- ALIGNMENTS -------------------------
    traces_alignments_homfam = get_computation_times(join(evaluation_dir, dataset), dataset, "alignments", extralevel=True)
    # ---------- CONCATENATE AL OF THEM IN ONE ---------------
    traces = pd.concat([traces_alignments_homfam], ignore_index=True)
    return(traces)

traces = extract_all_traces("homfam")
traces.name.str.split(".", expand = True)[1].value_counts()
# Out:
# regressive     378
# progressive    189
# dynamic         56
# Name: 1, dtype: int64

# %% [markdown]
# ## msa evaluation

# %%
dataset = "homfam"


eval_dir = join("/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/",dataset,"evaluation/CSV/")
scores_df = get_evaluation_all(eval_dir)
scores_df["benchmarking_dataset"] = dataset
scores_df["bucket_size"] = pd.to_numeric(scores_df.bucket_size)

# sep reference and full
scores_df["tag"] = scores_df.family.str.contains("_ref").map({True: 'ref', False: 'full'})
scores_df.family = scores_df.family.str.replace("_ref","")

scores_df.method.value_counts()
# Out:
# regressive     376
# progressive     94
# dynamic         56
# Name: method, dtype: int64

# %% [markdown]
# ## merge

# %%
stats = pd.merge(scores_df, traces, on = ["name","benchmarking_dataset"])
stats = pd.merge(stats, summary_homfam_exthomfam, on =["family","benchmarking_dataset"])
stats_alignments = stats[stats.task == "alignments"]
stats_alignments["approach"] = stats_alignments[["method", "bucket_size", "master_msa", "slave_msa", "dynamicX_val"]].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)
stats_alignments.head(1)
# Out:
#    index                                           name    sp   tc  column  \
# 0      0  tRNA-synt_2b.regressive.50.FAMSA.FAMSA-medoid  17.2  0.0     0.0
#
#          family      method  bucket_size master_msa          tree  ...  \
# 0  tRNA-synt_2b  regressive         50.0      FAMSA  FAMSA-medoid  ...
#
#          task    subset n_sequences mean_length min_length  max_length  \
# 0  alignments  combined       11293  177.564155         34         402
#
#            file  size_group  perc_ref_total                       approach
# 0  tRNA-synt_2b       large        0.044275  regressive_50.0_FAMSA_nan_nan
#
# [1 rows x 40 columns]

# %%
stats_alignments['has_ref'] = stats_alignments.groupby(["family", "approach"])["tag"].transform("count")>1

# %%
stats_alignments['has_ref'].value_counts()
# Out:
# True     376
# False    150
# Name: has_ref, dtype: int64

# %%
stats_alignments.tc.isna().value_counts()
# Out:
# False    526
# Name: tc, dtype: int64

# %% [markdown]
# # Dynamic params selection

# %%
metrics = [["sp", "sum of pairs"], ["tc", "total column"], ["column", "column"]]
metrics = [["tc", "total column"]]

# %% [markdown]
# ## DyanmicX

# %%
stats_alignments_dynamic = stats_alignments[stats_alignments.method =="dynamic"]

# %%
sns.set_context("talk")
#metrics = [["diff_sp", "sum of pairs"], ["diff_tc", "total column"], ["diff_column", "column"]]

for metric in metrics:
    f, ax = plt.subplots(figsize=(5, 4))
    sns.scatterplot(data=stats_alignments_dynamic, y=metric[0], x="n_sequences", hue="dynamicX_val",
                    palette = "magma", s = 50)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel=  metric[1], xlabel='number of sequences')

# %% [markdown]
# ## parent aligner

# %%
for metric in metrics:
    f, ax = plt.subplots(figsize=(5, 4))
    sns.scatterplot(data=stats_alignments_dynamic, y=metric[0], x="n_sequences", hue="master_msa",s = 50)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel=  metric[1], xlabel='number of sequences')

# %%
# try plotting with cumavg

for metric in metrics:
    f, ax = plt.subplots(figsize=(5, 4))

    x = stats_alignments_dynamic.n_sequences
    y = cumavg(stats_alignments_dynamic[metric[0]])
    hue = stats_alignments_dynamic["dynamicX_val"]
    sns.lineplot(x = x, y = y, hue=hue)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel=  metric[1], xlabel='number of sequences')

# %%
def cumavg(x): 
    return(x.cumsum()/list(range(len(x)+1)[1:]))

# %% [markdown]
# # Regressive

# %%
stats_alignments_regressive = stats_alignments[stats_alignments.method =="regressive"]

# %%
stats_alignments_regressive.family.str.contains("_ref").value_counts()
# Out:
# False    188
# Name: family, dtype: int64

# %%
stats_alignments_regressive.head(3)
# Out:
#    index                                             name    sp    tc  column  \
# 0      0    tRNA-synt_2b.regressive.50.FAMSA.FAMSA-medoid  17.2   0.0     0.0
# 1    331  tRNA-synt_2b.regressive.1000.FAMSA.FAMSA-medoid  58.0  30.2    41.9
# 3      1         sodcu.regressive.1000.FAMSA.FAMSA-medoid  70.3  45.8    48.5
#
#          family      method  bucket_size master_msa          tree  ...  \
# 0  tRNA-synt_2b  regressive         50.0      FAMSA  FAMSA-medoid  ...
# 1  tRNA-synt_2b  regressive       1000.0      FAMSA  FAMSA-medoid  ...
# 3         sodcu  regressive       1000.0      FAMSA  FAMSA-medoid  ...
#
#          task    subset n_sequences mean_length  min_length  max_length  \
# 0  alignments  combined       11293  177.564155          34         402
# 1  alignments  combined       11293  177.564155          34         402
# 3  alignments  combined        2038  141.322375          21         198
#
#            file  size_group  perc_ref_total                         approach
# 0  tRNA-synt_2b       large        0.044275    regressive_50.0_FAMSA_nan_nan
# 1  tRNA-synt_2b       large        0.044275  regressive_1000.0_FAMSA_nan_nan
# 3         sodcu       small        0.343474  regressive_1000.0_FAMSA_nan_nan
#
# [3 rows x 39 columns]

# %%
for metric in metrics:
    f, ax = plt.subplots(figsize=(5, 4))

    x = stats_alignments_regressive.n_sequences
    y = cumavg(stats_alignments_regressive[metric[0]])
    hue = stats_alignments_regressive["bucket_size"]
    sns.lineplot(x = x, y = y, hue=hue)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel=  metric[1], xlabel='number of sequences')

# %%
# get tc scores
x = stats_alignments.tc

# %%
x=pd.DataFrame([1,1,3]).cumsum()[0]
x
# Out:
# 0    1
# 1    2
# 2    5
# Name: 0, dtype: int64

# %%
x
# Out:
# 0       0.0
# 1      19.8
# 2      48.6
# 3      42.9
# 4      46.0
#        ...
# 239    63.2
# 240    28.3
# 241    60.2
# 242    16.4
# 243     4.1
# Name: tc, Length: 244, dtype: float64

# %%
x/
# Out:
# 0    1.000000
# 1    1.000000
# 2    1.666667
# Name: 0, dtype: float64

# %% [markdown]
# ## Plot average and std

# %%
nonreg_co_co_full<- nonreg_co_co[nonreg_co_co$tag == 'full',]
nonreg_co_co_ref<- nonreg_co_co[nonreg_co_co$tag == 'ref',]
nonreg_co_co_full_sorted <- nonreg_co_co_full[order(-nonreg_co_co_full$nseqs),]
nonreg_co_co_ref_sorted <- nonreg_co_co_ref[order(-nonreg_co_co_ref$nseqs),]
nonreg_co_co_diff <-  nonreg_co_co_full_sorted$tc_score - nonreg_co_co_ref_sorted$tc_score 
nonreg_co_co_cumsum <- cumsum(nonreg_co_co_diff)
nonreg_co_co_cumavg<-nonreg_co_co_cumsum/seq_along(nonreg_co_co_cumsum)
nonreg_co_co_cumsd<-sqrt(cum_var(nonreg_co_co_cumavg))
nonreg_co_co_cumsd[is.na(nonreg_co_co_cumsd)] <- 0

def cumsum(x): 
    return(list(x).cumsum())
def cum_var(x):
    ind_na = x.notna()
    nn = ind_na.cumsum()
    x[x.isna()] = 0
    cumsum(x^2) / (nn-1) - (cumsum(x))^2/(nn-1)/nn

# %%
x_cumsum = x.cumsum()
x_cumavg = x_cumsum/list(range(len(x)+1)[1:])
#x_cumstd = sqrt(cum_var(x_cumavg))
#x_cumstd[x_cumstd.isna()] = 0
x_cumavg
# Out:
# 0       0.000000
# 1       9.900000
# 2      22.800000
# 3      27.825000
# 4      31.460000
#          ...
# 239    50.238333
# 240    50.147303
# 241    50.188843
# 242    50.049794
# 243    49.861475
# Name: tc, Length: 244, dtype: float64

# %%
stats_reg = stats_alignments[stats_alignments.method == "regressive"]

# %% [markdown]
# ## visualize

# %%
stats_alignments = stats_alignments[stats_alignments.method in ["regressive","progressive"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27945/1103448600.py in <module>
# ----> 1 stats_alignments = stats_alignments[stats_alignments.method.item() in ["regressive","progressive"]]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/base.py in item(self)
#     329         if len(self) == 1:
#     330             return next(iter(self))
# --> 331         raise ValueError("can only convert an array of size 1 to a Python scalar")
#     332
#     333     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
# 1 - Does the dynamic improve accuracy ? 
# a. plot all 3 metrics (SUM etc) vs the number of sequences (Dynamic + Regressive on FAMSA)
sns.set_context("talk")
metrics = [["sp", "sum of pairs"], ["tc", "total column"], ["column", "column"]]
#metrics = [["diff_sp", "sum of pairs"], ["diff_tc", "total column"], ["diff_column", "column"]]

for metric in metrics:
    f, ax = plt.subplots(figsize=(12, 7))
    sns.lmplot(data=stats_reg, y=metric[0], x="n_sequences", hue="approach",
                    palette = "magma")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel= "differential " + metric[1], xlabel='number of sequences')
