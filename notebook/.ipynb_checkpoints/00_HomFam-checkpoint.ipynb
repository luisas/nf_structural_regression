# %% [markdown]
# # Explore Homfam

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import OrderedDict
from Bio import SeqIO


homfam_path_combined = "/home/luisasantus/Desktop/crg_cluster/data/structural_regression/homfam/combinedSeqs"
homfam_path_ref = "/home/luisasantus/Desktop/crg_cluster/data/structural_regression/homfam/refs"

outdir = "../../../data/structural_regression/plots/01_homfam/"

# %%
combined = "/home/luisasantus/Desktop/crg_cluster/data/structural_regression/homfam/combinedSeqs/hip.fa"
ref = "/home/luisasantus/Desktop/crg_cluster/data/structural_regression/homfam/combinedSeqs/hip.fa"

# %%
def get_stats(f):
    fasta_sequences = SeqIO.parse(open(f),'fasta')

    ls = []
    n_sequences = 0 

    for fasta in fasta_sequences:
        name, sequence = fasta.id, str(fasta.seq)
        n_sequences = n_sequences + 1
        l = len(sequence.replace("-", ""))
        ls.append(l)
    entry = pd.DataFrame({"file": [os.path.basename(f).replace(".fa", "")],
                          "n_sequences": [n_sequences],
                          "mean_length": [np.mean(ls)],
                          "min_length": [np.min(ls)],
                          "max_length": [np.max(ls)]})
    return(entry)

# %%
def get_summary_df(homfam_path, subset = ""):
    summary_homfam = pd.DataFrame()
    max_steps = float("Inf")
    i = 0 
    for filename in os.listdir(homfam_path):
        i = i+1
        if(i>max_steps): 
            break
        f = os.path.join(homfam_path, filename)
        # checking if it is a file
        if os.path.isfile(f):
            entry = get_stats(f)
            summary_homfam = summary_homfam.append(entry, ignore_index= True)
    summary_homfam["family"] = summary_homfam.file
    summary_homfam["subset"] = subset
    summary_homfam.sort_values(by=['family'])

    column_names = ["family", "subset", "n_sequences","mean_length", "min_length", "max_length", "file"]
    summary_homfam = summary_homfam.reindex(columns=column_names)
    return(summary_homfam)

# %%
summary_homfam_combined = get_summary_df(homfam_path, "combined")
summary_homfam_ref = get_summary_df(homfam_path, "combined")

# %%
summary_homfam.head()
# Out:
#           family subset  n_sequences  mean_length  min_length  max_length  \
# 0  Sulfotransfer   None         2489   235.798313          35         358
# 1            hpr   None         3349    83.042699          28         114
# 2         serpin   None         3144   291.461832          22         565
# 3             hr   None         3707    65.151335          17          89
# 4            ldh   None         7367   121.378309          27         333
#
#             file
# 0  Sulfotransfer
# 1            hpr
# 2         serpin
# 3             hr
# 4            ldh

# %%
summary_homfam_ref = summary_homfam[summary_homfam.subset == "ref"]
summary_homfam_test = summary_homfam[summary_homfam.subset == "test-only"].sort_values("n_sequences", ascending=False)

# %%
summary_homfam_merged = summary_homfam_ref.merge(summary_homfam_test,on='family')
summary_homfam_merged["perc_ref_total"] = (summary_homfam_merged.n_sequences_x * 100)/(summary_homfam_merged.n_sequences_x+summary_homfam_merged.n_sequences_y)

# %%
sns.set_theme(style="whitegrid")
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(11, 15))


# Plot the total crashes
sns.set_color_codes("pastel")
sns.set_color_codes("muted")
sns.barplot(x="n_sequences", y="family", data=summary_homfam_test,
            label="Test", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="number of sequences")
sns.despine(left=True, bottom=True)
plt.savefig(os.path.join(outdir, "01_test_seq.pdf"))

# %%
# Order as the one above
order_test =  list(OrderedDict.fromkeys(summary_homfam_test.family))
order_test
summary_homfam_ref['family'] = pd.Categorical(
    summary_homfam_ref['family'], 
    categories=order_test, 
    ordered=True
)


sns.set_theme(style="whitegrid")
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(11, 15))


# Plot the total crashes
sns.set_color_codes("pastel")
sns.set_color_codes("muted")
sns.barplot(x="n_sequences", y="family", data=summary_homfam_ref,
            label="Ref", color="r")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="number of sequences")
sns.despine(left=True, bottom=True)
plt.savefig(os.path.join(outdir, "02_refs_seq.pdf"))
# Out:
# /tmp/ipykernel_600490/349739958.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_homfam_ref['family'] = pd.Categorical(

# %%
summary_homfam_merged.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54428/907302894.py in <module>
# ----> 1 summary_homfam_merged.head(2)
#
# NameError: name 'summary_homfam_merged' is not defined

# %%
summary_homfam_merged['family'] = pd.Categorical(
    summary_homfam_merged['family'], 
    categories=order_test, 
    ordered=True
)
summary_homfam_merged

sns.set_theme(style="whitegrid")
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(11, 15))


# Plot the total crashes
sns.set_color_codes("pastel")
sns.set_color_codes("muted")
sns.barplot(x="perc_ref_total", y="family", data=summary_homfam_merged,
            label="% refs in family", color="g")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="number of sequences")
sns.despine(left=True, bottom=True)
plt.savefig(os.path.join(outdir, "03_perc_ref_in_family.pdf"))

# %%
summary_homfam[summary_homfam.family == "seatoxin"]
# Out:
#        family     subset  n_sequences  mean_length  min_length  max_length  \
# 113  seatoxin        ref            5    48.000000          44          50
# 139  seatoxin  test-only           88    44.443182          35          51
#
#                    file
# 113        seatoxin_ref
# 139  seatoxin_test-only
