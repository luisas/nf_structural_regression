# %% [markdown]
# # Benchmark structural regression

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import matplotlib.ticker as ticker

# %%
evaluation_dir = "/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/"
outdir = "../../../data/structural_regression/plots/02_benchmarkCPU/"

# %%
### parse trace files
def parse_trace(result_dir):
    f = os.path.basename(result_dir)
    name_trace = ".command.trace"
    trace = join(result_dir, name_trace)
    df = pd.read_csv(trace, sep = "=").T
    df = df.rename(index={'nextflow.trace/v2': f})
    return(df)

def split_name(df):
    df[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val",
               "master_msa", "master_batch",
               "slave_msa", "slave_batch","tree"]] = df.name.str.split(".", expand = True)
    return(df)


### Collect all computation files across directories 
def get_computation_times(evaluation_dir, dataset, task, extralevel = False, splitname =False):
    # Extract trace files w/ corresponding alignments
    traces = pd.DataFrame()
    alignments_dir = join(evaluation_dir,task)
    for fam in listdir(alignments_dir):
        family_dir=join(alignments_dir, fam)
        
        # remove extra level if needed
        if extralevel == False:
            family_dir = alignments_dir
            
        for f in listdir(family_dir):
            result_dir = join(family_dir,f)
            if(os.path.isdir(result_dir)):
                df = parse_trace(result_dir)
                traces = traces.append(df)
                
        if extralevel == False:
            break
    # Trace files parsed
    traces = traces.reset_index(level=0)
    traces = traces.rename(columns={'index': 'name'})
    traces["benchmarking_dataset"] = dataset
    if splitname: 
        traces = split_name(traces)
    
    traces["task"] = task
    return(traces)

# %%
def add_families(trees_traces):
    trees_traces["family"] = trees_traces.name.str.split(".",expand=True)[0]
    trees_traces["tree_method"] = trees_traces.name.str.split(".",expand=True)[1]
    return(trees_traces)

# %% [markdown]
# #### Load datasets informations (Homfam + extHomfam)

# %%
summary_homfam_exthomfam = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/01_summary_homfam_exthomfam.csv")
summary_homfam_exthomfam = summary_homfam_exthomfam.rename(columns={"dataset": "benchmarking_dataset"})
summary_homfam_exthomfam.head(2)
# Out:
#     family    subset  n_sequences  mean_length  min_length  max_length  \
# 0      rvp  combined        93681    94.288554          22         133
# 1  zf-CCHH  combined        88345    23.251265          12          35
#
#       file size_group  perc_ref_total benchmarking_dataset
# 0      rvp     xlarge        0.006405               homfam
# 1  zf-CCHH     xlarge        0.016979               homfam

# %% [markdown]
# # <div style="text-align: center;"> <span align="center" style="color:blue">_________TREES_________</span> </div>

# %%
trees_traces_homfam = get_computation_times(join(evaluation_dir, "homfam"), "homfam", "trees", extralevel=True, splitname=False)
trees_traces_homfam = add_families(trees_traces_homfam)

trees_traces_exthomfam_v35 = get_computation_times(join(evaluation_dir, "extHomfam_v35-uniprot"), "extHomfam_v35-uniprot", "trees", extralevel=True, splitname=False)
trees_traces_exthomfam_v35 = add_families(trees_traces_exthomfam_v35)

trees_traces = pd.concat([trees_traces_homfam, trees_traces_exthomfam_v35])

stat_trees = pd.merge(trees_traces, summary_homfam_exthomfam, on =["family","benchmarking_dataset"])
stat_trees.head(2)
# Out:
#                  name  realtime  %cpu   rchar  wchar  syscr  syscw  \
# 0  il8.FAMSA-parttree        81   600  138715  30817    142     22
# 1    il8.FAMSA-medoid       379   829  138725  30822    142     22
#
#    read_bytes  write_bytes  %mem  ...  family     tree_method    subset  \
# 0     1024000        32768     0  ...     il8  FAMSA-parttree  combined
# 1     1024000        32768     0  ...     il8    FAMSA-medoid  combined
#
#    n_sequences  mean_length  min_length max_length file size_group  \
# 0         1073    63.762349          18         82  il8      small
# 1         1073    63.762349          18         82  il8      small
#
#   perc_ref_total
# 0       1.025163
# 1       1.025163
#
# [2 rows x 28 columns]

# %%
# Remove outliers for visualization 
stat_trees_nooutlier = stat_trees.sort_values(by=['realtime'], ascending=False).iloc[12:]
stat_trees_nooutlier = stat_trees_nooutlier.sort_values(by=['realtime'])
outliers = stat_trees.sort_values(by=['realtime'], ascending=False).iloc[:12]
#outliers.size_group

# %%
sns.set_theme(style="ticks")
sns.set_context("talk")

# Load the example tips dataset
f, ax = plt.subplots(figsize=(10, 7))
df = stat_trees_nooutlier
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="size_group", y="realtime",
            hue="tree_method", palette = "magma",
            data=df, linewidth=1.5, fliersize = 1.5, dodge = True)

# Calculate number of obs per group & median to position labels
nobs = df['size_group'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]
 
# Add it to the plot
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick],
            -280000,
            nobs[tick],
            horizontalalignment='center',
            size='small',
            color='b')
 


ax.set(ylabel='CPU time (s)', xlabel='', title = "Both on homfam and extHomfam_v35-uniprot")
plt.legend(bbox_to_anchor=(1.05, 0.8), loc=2, borderaxespad=0.)

sns.despine(offset=10, trim=True)


ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) ))
plt.subplots_adjust(right=0.70, bottom = 0.20)
plt.savefig(os.path.join(outdir, "10_treesCPU.pdf"))

# %%
#stat_trees[stat_trees.realtime == max(stat_trees.realtime)]
# Out:
#                           name   realtime  %cpu     rchar    wchar  syscr  \
# 823  transket_pyr.FAMSA-medoid  303846676     2  28024387  4341395   3546
#
#      syscw   read_bytes  write_bytes  %mem  ...        family   tree_method  \
# 823     22  96014824448      4341760     1  ...  transket_pyr  FAMSA-medoid
#
#        subset  n_sequences  mean_length  min_length max_length          file  \
# 823  combined       144526    168.60138          26        288  transket_pyr
#
#     size_group perc_ref_total
# 823     xlarge       0.002076
#
# [1 rows x 28 columns]

# %%
#f, ax = plt.subplots(figsize=(7, 7))
#sns.scatterplot(data=stat_trees, y="realtime", x="n_sequences", hue="tree_method",
#                palette = "magma",style = "benchmarking_dataset", s = 30)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#ax.set(ylabel='CPU time (s)', xlabel='number of sequences')
#ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) ))
#ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000)+"K" ))

# %% [markdown]
# # <div style="text-align: center;"> <span align="center" style="color:red">_________Computation times_________</span> </div>

# %%
def extract_all_traces(dataset):
    # ---------- EXTRACT SEQUENCES ---------------
    traces_extracted_sequences_homfam = get_computation_times(join(evaluation_dir, dataset), dataset, "seqs_extracted")
    # ---------- AF2 PREDICTIONS -------------------------
    # traces_af2_homfam = get_computation_times(join(evaluation_dir, dataset), dataset, "structures/colabfold")
    # ---------- ALIGNMENTS -------------------------
    traces_alignments_homfam = get_computation_times(join(evaluation_dir, dataset), dataset, "alignments", extralevel=True)
    # ---------- CONCATENATE AL OF THEM IN ONE ---------------
    traces = pd.concat([traces_extracted_sequences_homfam,traces_alignments_homfam], ignore_index=True)
    return(traces)

# %%
traces = extract_all_traces("homfam")

# %%
traces.name.str.split(".", expand = True)[1].value_counts()
# Out:
# dynamic        80
# regressive     52
# progressive     8
# Name: 1, dtype: int64

# %% [markdown]
# # <div style="text-align: center;"> <span align="center" style="color:balck">_________Load Evaluation_________</span> </div>

# %%
# Load AF2 scores
af2 = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/02_summary_af2.csv")
af2_grouped = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/03_summary_af2_grouped.csv")

# %%
my_dir = join("/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/",dataset,"evaluation/CSV/")

# %%
csv_file
# Out:
# 'regressive.scores_[FAMSA]_50.csv'

# %%
def get_evaluation(my_dir, csv_file, splitname = True):
    
    scores = join(my_dir, csv_file)    
    scores_df = pd.read_csv(scores, sep=";", header = None).iloc[: , :-1]
    scores_df.set_axis(list(["name", "sp","tc", "column"]), axis=1, inplace=True)
    
    method = csv_file.split(".")[0]
    
    if splitname:
        if method == "dynamic": 
            scores_df[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val",
                       "master_msa", "master_batch",
                       "slave_msa", "slave_batch","tree"]] = scores_df.name.str.split(".", expand = True)
        elif method == "regressive":
            scores_df[["family", "method", "bucket_size",
                       "master_msa","tree"]] = scores_df.name.str.split(".", expand = True)
        elif method == "progressive":
            scores_df[["family", "method",
                       "master_msa","tree"]] = scores_df.name.str.split(".", expand = True)        
    scores_df["benchmarking_dataset"] = dataset
    return(scores_df)

def get_evaluation_all(my_dir):
    all_files = os.listdir(my_dir)    
    csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
    df  = pd.DataFrame()
    for file in csv_files: 
        df = pd.concat(list([df, get_evaluation(my_dir, file)]))
    return(df)

# %%
scores_df = get_evaluation_all(my_dir)
scores_df["bucket_size"] = pd.to_numeric(scores_df.bucket_size)
scores_df.method.value_counts()
# Out:
# regressive     16
# progressive     8
# dynamic         8
# Name: method, dtype: int64

# %% [markdown]
# # <div style="text-align: center;"> <span align="center" style="color:lightgrey">_________MERGE_________</span> </div>

# %%
stats = pd.merge(scores_df, traces, on = ["name","benchmarking_dataset"])
traces.name[1]
# Out:
# 'hip.dynamic.30.dynamicX.1.tcoffee_msa.50.famsa_msa.100.FAMSA-medoid'

# %%
stats = pd.merge(scores_df, traces, on = ["name","benchmarking_dataset"])
stats = pd.merge(stats, summary_homfam_exthomfam, on =["family","benchmarking_dataset"])
stats.head()
# Out:
#                                                 name    sp    tc  column  \
# 0  seatoxin.dynamic.50.dynamicX.1.famsa_msa.50.fa...  80.3  44.9    44.7
# 1  seatoxin.dynamic.50.dynamicX.1.famsa_msa.50.fa...  80.3  44.9    44.7
# 2  seatoxin.dynamic.30.dynamicX.1.tcoffee_msa.50....  79.9  53.1    52.8
# 3  seatoxin.dynamic.30.dynamicX.1.tcoffee_msa.50....  79.9  53.1    52.8
# 4  seatoxin.dynamic.10.dynamicX.1.tcoffee_msa.50....  82.4  57.1    55.8
#
#      family   method  bucket_size dynamicX_label dynamicX_val   master_msa  \
# 0  seatoxin  dynamic         50.0       dynamicX            1    famsa_msa
# 1  seatoxin  dynamic         50.0       dynamicX            1    famsa_msa
# 2  seatoxin  dynamic         30.0       dynamicX            1  tcoffee_msa
# 3  seatoxin  dynamic         30.0       dynamicX            1  tcoffee_msa
# 4  seatoxin  dynamic         10.0       dynamicX            1  tcoffee_msa
#
#    ... inv_ctxt            task    subset n_sequences mean_length  min_length  \
# 0  ...        3  seqs_extracted  combined          93   43.634409          34
# 1  ...        2      alignments  combined          93   43.634409          34
# 2  ...        3  seqs_extracted  combined          93   43.634409          34
# 3  ...     1157      alignments  combined          93   43.634409          34
# 4  ...        4  seqs_extracted  combined          93   43.634409          34
#
#    max_length      file  size_group  perc_ref_total
# 0          50  seatoxin       small        5.376344
# 1          50  seatoxin       small        5.376344
# 2          50  seatoxin       small        5.376344
# 3          50  seatoxin       small        5.376344
# 4          50  seatoxin       small        5.376344
#
# [5 rows x 39 columns]

# %% [markdown]
# # <div style="text-align: center;"> <span align="center" style="color:blue">_________VISUALIZE_________</span> </div>

# %%
stats_alignments = stats[stats.task == "alignments"]
stats_alignments.head(2)
# Out:
#                                                 name    sp    tc  column  \
# 1  seatoxin.dynamic.50.dynamicX.1.famsa_msa.50.fa...  80.3  44.9    44.7
# 3  seatoxin.dynamic.30.dynamicX.1.tcoffee_msa.50....  79.9  53.1    52.8
#
#      family   method  bucket_size dynamicX_label dynamicX_val   master_msa  \
# 1  seatoxin  dynamic         50.0       dynamicX            1    famsa_msa
# 3  seatoxin  dynamic         30.0       dynamicX            1  tcoffee_msa
#
#    ... inv_ctxt        task    subset n_sequences mean_length  min_length  \
# 1  ...        2  alignments  combined          93   43.634409          34
# 3  ...     1157  alignments  combined          93   43.634409          34
#
#    max_length      file  size_group  perc_ref_total
# 1          50  seatoxin       small        5.376344
# 3          50  seatoxin       small        5.376344
#
# [2 rows x 39 columns]

# %%
stats_alignments = stats[stats.task == "alignments"]
stats_alignments_progressive = stats_alignments[stats_alignments.method == "progressive"]


stats_alignments_50 = stats_alignments.loc[stats_alignments['bucket_size'].isin(list([50]))]
stats_alignments_30 = stats_alignments.loc[stats_alignments['bucket_size'].isin(list([30]))]
stats_alignments_10 = stats_alignments.loc[stats_alignments['bucket_size'].isin(list([10]))]


stats_alignments_regressive = stats_alignments_50[stats_alignments_50.method == "regressive"]

stats_alignments_dynamic_50 = stats_alignments_50[stats_alignments_50.method == "dynamic"]
stats_alignments_dynamic_30 = stats_alignments_30[stats_alignments_30.method == "dynamic"]
stats_alignments_dynamic_10 = stats_alignments_10[stats_alignments_10.method == "dynamic"]

# %%
def get_relative_tc(stats_alignments_dynamic, stats_alignments_regressive = stats_alignments_regressive):
    # sort dataframes 
    dynamic_df_sorted = stats_alignments_dynamic[variables].sort_values(variables)
    regressive_df_sorted = stats_alignments_regressive[variables].sort_values(variables)

    dynamic = np.array(dynamic_df_sorted.tc)
    regressive = np.array(regressive_df_sorted.tc)

    delta = dynamic - regressive
    perc_change = (dynamic - regressive)*100/dynamic

    dynamic_df_sorted["delta"] = delta
    dynamic_df_sorted["perc_change"] = perc_change

    # add family size 
    famsize = stats[list(["family", "n_sequences"])].drop_duplicates()
    dy_vs_reg = dynamic_df_sorted.sort_values(variables).merge(famsize, on=["family"])
    dy_vs_reg = dy_vs_reg.sort_values("n_sequences")
    return(dy_vs_reg)

# %%
stats_alignments_regressive
# Out:
#                                            name    sp    tc  column  \
# 6     seatoxin.regressive.50.FAMSA.FAMSA-medoid  80.3  44.9    44.7
# 16         TNF.regressive.50.FAMSA.FAMSA-medoid  83.9  61.8    67.0
# 26         sti.regressive.50.FAMSA.FAMSA-medoid  72.3  45.1    51.0
# 36         hip.regressive.50.FAMSA.FAMSA-medoid  86.3  64.3    72.8
# 46    rnasemam.regressive.50.FAMSA.FAMSA-medoid  87.1  59.0    65.7
# 56  scorptoxin.regressive.50.FAMSA.FAMSA-medoid  93.1  76.7    86.3
# 66       ghf11.regressive.50.FAMSA.FAMSA-medoid  71.2  50.5    50.3
# 76       toxin.regressive.50.FAMSA.FAMSA-medoid  73.7  28.6    28.8
#
#         family      method  bucket_size dynamicX_label dynamicX_val  \
# 6     seatoxin  regressive         50.0            NaN          NaN
# 16         TNF  regressive         50.0            NaN          NaN
# 26         sti  regressive         50.0            NaN          NaN
# 36         hip  regressive         50.0            NaN          NaN
# 46    rnasemam  regressive         50.0            NaN          NaN
# 56  scorptoxin  regressive         50.0            NaN          NaN
# 66       ghf11  regressive         50.0            NaN          NaN
# 76       toxin  regressive         50.0            NaN          NaN
#
#    master_msa  ... inv_ctxt        task    subset n_sequences mean_length  \
# 6       FAMSA  ...        4  alignments  combined          93   43.634409
# 16      FAMSA  ...       48  alignments  combined         556  119.902878
# 26      FAMSA  ...       19  alignments  combined         613  165.383361
# 36      FAMSA  ...       12  alignments  combined         167   66.209581
# 46      FAMSA  ...       33  alignments  combined         498  120.072289
# 56      FAMSA  ...       13  alignments  combined         363   53.256198
# 66      FAMSA  ...       58  alignments  combined         521  167.758157
# 76      FAMSA  ...       12  alignments  combined         508   62.311024
#
#     min_length  max_length        file  size_group  perc_ref_total
# 6           34          50    seatoxin       small        5.376344
# 16          33         163         TNF       small        0.899281
# 26          32         193         sti       small        0.815661
# 36          54          85         hip       small        2.994012
# 46          62         140    rnasemam       small        1.204819
# 56          22          69  scorptoxin       small        2.203857
# 66          26         227       ghf11       small        0.959693
# 76          30          77       toxin       small        3.937008
#
# [8 rows x 39 columns]

# %%
stats_alignments_dynamic
# Out:
#                                                  name    sp    tc  column  \
# 1   seatoxin.dynamic.50.dynamicX.1.famsa_msa.50.fa...  80.3  44.9    44.7
# 11  TNF.dynamic.50.dynamicX.1.famsa_msa.50.famsa_m...  83.9  61.8    67.0
# 21  sti.dynamic.50.dynamicX.1.famsa_msa.50.famsa_m...  72.3  45.1    51.0
# 31  hip.dynamic.50.dynamicX.1.famsa_msa.50.famsa_m...  86.3  64.3    72.8
# 41  rnasemam.dynamic.50.dynamicX.1.famsa_msa.50.fa...  87.1  59.0    65.7
# 51  scorptoxin.dynamic.50.dynamicX.1.famsa_msa.50....  93.1  76.7    86.3
# 61  ghf11.dynamic.50.dynamicX.1.famsa_msa.50.famsa...  71.2  50.5    50.3
# 71  toxin.dynamic.50.dynamicX.1.famsa_msa.50.famsa...  73.7  28.6    28.8
#
#         family   method  bucket_size dynamicX_label dynamicX_val master_msa  \
# 1     seatoxin  dynamic         50.0       dynamicX            1  famsa_msa
# 11         TNF  dynamic         50.0       dynamicX            1  famsa_msa
# 21         sti  dynamic         50.0       dynamicX            1  famsa_msa
# 31         hip  dynamic         50.0       dynamicX            1  famsa_msa
# 41    rnasemam  dynamic         50.0       dynamicX            1  famsa_msa
# 51  scorptoxin  dynamic         50.0       dynamicX            1  famsa_msa
# 61       ghf11  dynamic         50.0       dynamicX            1  famsa_msa
# 71       toxin  dynamic         50.0       dynamicX            1  famsa_msa
#
#     ... inv_ctxt        task    subset n_sequences mean_length  min_length  \
# 1   ...        2  alignments  combined          93   43.634409          34
# 11  ...       12  alignments  combined         556  119.902878          33
# 21  ...        5  alignments  combined         613  165.383361          32
# 31  ...       13  alignments  combined         167   66.209581          54
# 41  ...       14  alignments  combined         498  120.072289          62
# 51  ...       14  alignments  combined         363   53.256198          22
# 61  ...       14  alignments  combined         521  167.758157          26
# 71  ...       13  alignments  combined         508   62.311024          30
#
#     max_length        file  size_group  perc_ref_total
# 1           50    seatoxin       small        5.376344
# 11         163         TNF       small        0.899281
# 21         193         sti       small        0.815661
# 31          85         hip       small        2.994012
# 41         140    rnasemam       small        1.204819
# 51          69  scorptoxin       small        2.203857
# 61         227       ghf11       small        0.959693
# 71          77       toxin       small        3.937008
#
# [8 rows x 39 columns]

# %%
pro_vs_reg = get_relative_tc(stats_alignments_progressive)
dyn_vs_reg = get_relative_tc(stats_alignments_dynamic)

# Calc differential TC 
differential_tc_vs_reg50 = pd.concat(list([pro_vs_reg,dyn_vs_reg]))
differential_tc_vs_reg50["method_extended"] = differential_tc_vs_reg50.method + "_" +differential_tc_vs_reg50.bucket_size.astype(str)

# %%
differential_tc_vs_reg50
# Out:
#         method      family  bucket_size    tc  delta  perc_change  \
# 5  progressive    seatoxin          NaN  46.9    2.0     4.264392
# 2  progressive         hip          NaN  58.3   -6.0   -10.291595
# 4  progressive  scorptoxin          NaN  63.0  -13.7   -21.746032
# 3  progressive    rnasemam          NaN  65.7    6.7    10.197869
# 7  progressive       toxin          NaN  53.2   24.6    46.240602
# 1  progressive       ghf11          NaN  82.3   31.8    38.639125
# 0  progressive         TNF          NaN  52.9   -8.9   -16.824197
# 6  progressive         sti          NaN  44.0   -1.1    -2.500000
# 5      dynamic    seatoxin         50.0  44.9    0.0     0.000000
# 2      dynamic         hip         50.0  64.3    0.0     0.000000
# 4      dynamic  scorptoxin         50.0  76.7    0.0     0.000000
# 3      dynamic    rnasemam         50.0  59.0    0.0     0.000000
# 7      dynamic       toxin         50.0  28.6    0.0     0.000000
# 1      dynamic       ghf11         50.0  50.5    0.0     0.000000
# 0      dynamic         TNF         50.0  61.8    0.0     0.000000
# 6      dynamic         sti         50.0  45.1    0.0     0.000000
#
#    n_sequences  method_extended
# 5           93  progressive_nan
# 2          167  progressive_nan
# 4          363  progressive_nan
# 3          498  progressive_nan
# 7          508  progressive_nan
# 1          521  progressive_nan
# 0          556  progressive_nan
# 6          613  progressive_nan
# 5           93     dynamic_50.0
# 2          167     dynamic_50.0
# 4          363     dynamic_50.0
# 3          498     dynamic_50.0
# 7          508     dynamic_50.0
# 1          521     dynamic_50.0
# 0          556     dynamic_50.0
# 6          613     dynamic_50.0

# %%
# Plot differential TC 
sns.set_theme(style="white", context="talk")

rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, ax = plt.subplots(1, 1, figsize=(15, 6), sharex=True)

# Generate some sequential data
sns.barplot(x="family", y="perc_change",data = differential_tc_vs_reg50, palette="rocket", hue = "method_extended")
ax.axhline(0, color="k", clip_on=False)


# Calculate number of obs per group & median to position labels
nobs =  dy_vs_reg[list(["family", "n_sequences"])].drop_duplicates().n_sequences
nobs = [str(x) for x in nobs.tolist()]
nobs = ["#seq: \n" + i for i in nobs]
 
# Add it to the plot
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick],
            -150,
            nobs[tick],
            horizontalalignment='center',
            size='medium',
            color='b')


ax.set_ylabel("differential total column score (%)")
ax.set_title("dynamic vs regressive. reference: regressive.")
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.05, 0.8), loc=2, title= "bucket size", borderaxespad=0.)
ax.set(ylim=(-100, 100))
# Out:
# [(-100.0, 100.0)]

# %%
# Plot differential TC 
sns.set_theme(style="white", context="talk")

rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, ax = plt.subplots(1, 1, figsize=(15, 6), sharex=True)

# Generate some sequential data
sns.barplot(x="family", y="perc_change",data = dyn_vs_reg, palette="Greys", hue = "bucket_size")
ax.axhline(0, color="k", clip_on=False)


# Calculate number of obs per group & median to position labels
nobs =  dy_vs_reg[list(["family", "n_sequences"])].drop_duplicates().n_sequences
nobs = [str(x) for x in nobs.tolist()]
nobs = ["#seq: \n" + i for i in nobs]
 
# Add it to the plot
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick],
            -150,
            nobs[tick],
            horizontalalignment='center',
            size='medium',
            color='b')


ax.set_ylabel("differential total column score (%)")
ax.set_title("dynamic vs regressive. reference: regressive.")
ax.set_xlabel("")
plt.legend(bbox_to_anchor=(1.05, 0.8), loc=2, title= "bucket size", borderaxespad=0.)
ax.set(ylim=(-100, 100))
# Out:
# [(-100.0, 100.0)]

# %%
# --------------   TODO -----------------
# 1 - Does the dynamic improve accuracy ? 
# a. plot all 3 metrics (SUM etc) vs the number of sequences (Dynamic + Regressive on FAMSA)
# 2 - At which computational loss? 
# b. plot all 3 metrics (SUM etc) vs the CPU time (aligner only) (Dynamic + Regressive on FAMSA)
# c. plot all 3 metrics (SUM etc) vs the CPU time (aligner only AND aligner + extract + prediction) (Dynamic + Regressive on FAMSA)
# 3 - confront gain in accuracy? Accuracy Dynamic vs Accuracy regressive
# 4 - cnfront loss in speed - cpu time dynamic vs regressive

# %%
stats_alignments
# Out:
#                                                  name    sp    tc  column  \
# 1   seatoxin.dynamic.50.dynamicX.1.famsa_msa.50.fa...  80.3  44.9    44.7
# 3   seatoxin.dynamic.30.dynamicX.1.tcoffee_msa.50....  79.9  53.1    52.8
# 5   seatoxin.dynamic.10.dynamicX.1.tcoffee_msa.50....  82.4  57.1    55.8
# 6           seatoxin.regressive.50.FAMSA.FAMSA-medoid  80.3  44.9    44.7
# 7           seatoxin.regressive.30.FAMSA.FAMSA-medoid  79.6  44.9    44.7
# 8           seatoxin.regressive.10.FAMSA.FAMSA-medoid  83.6  55.1    53.7
# 9             seatoxin.progressive.FAMSA.FAMSA-medoid  80.1  46.9    47.0
# 11  TNF.dynamic.50.dynamicX.1.famsa_msa.50.famsa_m...  83.9  61.8    67.0
# 13  TNF.dynamic.30.dynamicX.1.tcoffee_msa.50.famsa...  93.1  80.3    86.9
# 15  TNF.dynamic.10.dynamicX.1.tcoffee_msa.50.famsa...  88.8  72.6    78.6
# 16               TNF.regressive.50.FAMSA.FAMSA-medoid  83.9  61.8    67.0
# 17               TNF.regressive.30.FAMSA.FAMSA-medoid  81.4  64.3    69.2
# 18               TNF.regressive.10.FAMSA.FAMSA-medoid  72.0  47.8    53.4
# 19                 TNF.progressive.FAMSA.FAMSA-medoid  77.8  52.9    56.8
# 21  sti.dynamic.50.dynamicX.1.famsa_msa.50.famsa_m...  72.3  45.1    51.0
# 23  sti.dynamic.30.dynamicX.1.tcoffee_msa.50.famsa...  84.6  66.8    75.3
# 25  sti.dynamic.10.dynamicX.1.tcoffee_msa.50.famsa...  74.4  45.1    51.5
# 26               sti.regressive.50.FAMSA.FAMSA-medoid  72.3  45.1    51.0
# 27               sti.regressive.30.FAMSA.FAMSA-medoid  76.4  48.9    55.8
# 28               sti.regressive.10.FAMSA.FAMSA-medoid  74.4  45.1    51.5
# 29                 sti.progressive.FAMSA.FAMSA-medoid  76.2  44.0    47.5
# 31  hip.dynamic.50.dynamicX.1.famsa_msa.50.famsa_m...  86.3  64.3    72.8
# 33  hip.dynamic.30.dynamicX.1.tcoffee_msa.50.famsa...  87.3  66.7    69.6
# 35  hip.dynamic.10.dynamicX.1.tcoffee_msa.50.famsa...  85.2  59.5    69.2
# 36               hip.regressive.50.FAMSA.FAMSA-medoid  86.3  64.3    72.8
# 37               hip.regressive.30.FAMSA.FAMSA-medoid  78.4  51.2    58.3
# 38               hip.regressive.10.FAMSA.FAMSA-medoid  76.4  44.0    51.8
# 39                 hip.progressive.FAMSA.FAMSA-medoid  85.3  58.3    68.7
# 41  rnasemam.dynamic.50.dynamicX.1.famsa_msa.50.fa...  87.1  59.0    65.7
# 43  rnasemam.dynamic.30.dynamicX.1.tcoffee_msa.50....  90.0  67.2    75.5
# 45  rnasemam.dynamic.10.dynamicX.1.tcoffee_msa.50....  83.8  51.5    57.7
# 46          rnasemam.regressive.50.FAMSA.FAMSA-medoid  87.1  59.0    65.7
# 47          rnasemam.regressive.30.FAMSA.FAMSA-medoid  88.4  63.4    71.0
# 48          rnasemam.regressive.10.FAMSA.FAMSA-medoid  79.2  41.0    46.1
# 49            rnasemam.progressive.FAMSA.FAMSA-medoid  92.8  65.7    76.6
# 51  scorptoxin.dynamic.50.dynamicX.1.famsa_msa.50....  93.1  76.7    86.3
# 53  scorptoxin.dynamic.30.dynamicX.1.tcoffee_msa.5...  94.7  84.9    87.9
# 55  scorptoxin.dynamic.10.dynamicX.1.tcoffee_msa.5...  91.7  76.7    82.1
# 56        scorptoxin.regressive.50.FAMSA.FAMSA-medoid  93.1  76.7    86.3
# 57        scorptoxin.regressive.30.FAMSA.FAMSA-medoid  90.5  69.9    77.9
# 58        scorptoxin.regressive.10.FAMSA.FAMSA-medoid  90.2  71.2    76.9
# 59          scorptoxin.progressive.FAMSA.FAMSA-medoid  87.5  63.0    73.9
# 61  ghf11.dynamic.50.dynamicX.1.famsa_msa.50.famsa...  71.2  50.5    50.3
# 63  ghf11.dynamic.30.dynamicX.1.tcoffee_msa.50.fam...  82.1  66.1    66.9
# 65  ghf11.dynamic.10.dynamicX.1.tcoffee_msa.50.fam...  67.6  47.9    50.6
# 66             ghf11.regressive.50.FAMSA.FAMSA-medoid  71.2  50.5    50.3
# 67             ghf11.regressive.30.FAMSA.FAMSA-medoid  76.2  55.2    55.9
# 68             ghf11.regressive.10.FAMSA.FAMSA-medoid  71.0  50.5    53.4
# 69               ghf11.progressive.FAMSA.FAMSA-medoid  93.2  82.3    84.0
# 71  toxin.dynamic.50.dynamicX.1.famsa_msa.50.famsa...  73.7  28.6    28.8
# 73  toxin.dynamic.30.dynamicX.1.tcoffee_msa.50.fam...  76.2  36.4    38.1
# 75  toxin.dynamic.10.dynamicX.1.tcoffee_msa.50.fam...  66.0  24.7    23.6
# 76             toxin.regressive.50.FAMSA.FAMSA-medoid  73.7  28.6    28.8
# 77             toxin.regressive.30.FAMSA.FAMSA-medoid  69.4  27.3    27.1
# 78             toxin.regressive.10.FAMSA.FAMSA-medoid  62.2  24.7    23.6
# 79               toxin.progressive.FAMSA.FAMSA-medoid  90.1  53.2    59.4
#
#         family       method  bucket_size dynamicX_label dynamicX_val  \
# 1     seatoxin      dynamic         50.0       dynamicX            1
# 3     seatoxin      dynamic         30.0       dynamicX            1
# 5     seatoxin      dynamic         10.0       dynamicX            1
# 6     seatoxin   regressive         50.0            NaN          NaN
# 7     seatoxin   regressive         30.0            NaN          NaN
# 8     seatoxin   regressive         10.0            NaN          NaN
# 9     seatoxin  progressive          NaN            NaN          NaN
# 11         TNF      dynamic         50.0       dynamicX            1
# 13         TNF      dynamic         30.0       dynamicX            1
# 15         TNF      dynamic         10.0       dynamicX            1
# 16         TNF   regressive         50.0            NaN          NaN
# 17         TNF   regressive         30.0            NaN          NaN
# 18         TNF   regressive         10.0            NaN          NaN
# 19         TNF  progressive          NaN            NaN          NaN
# 21         sti      dynamic         50.0       dynamicX            1
# 23         sti      dynamic         30.0       dynamicX            1
# 25         sti      dynamic         10.0       dynamicX            1
# 26         sti   regressive         50.0            NaN          NaN
# 27         sti   regressive         30.0            NaN          NaN
# 28         sti   regressive         10.0            NaN          NaN
# 29         sti  progressive          NaN            NaN          NaN
# 31         hip      dynamic         50.0       dynamicX            1
# 33         hip      dynamic         30.0       dynamicX            1
# 35         hip      dynamic         10.0       dynamicX            1
# 36         hip   regressive         50.0            NaN          NaN
# 37         hip   regressive         30.0            NaN          NaN
# 38         hip   regressive         10.0            NaN          NaN
# 39         hip  progressive          NaN            NaN          NaN
# 41    rnasemam      dynamic         50.0       dynamicX            1
# 43    rnasemam      dynamic         30.0       dynamicX            1
# 45    rnasemam      dynamic         10.0       dynamicX            1
# 46    rnasemam   regressive         50.0            NaN          NaN
# 47    rnasemam   regressive         30.0            NaN          NaN
# 48    rnasemam   regressive         10.0            NaN          NaN
# 49    rnasemam  progressive          NaN            NaN          NaN
# 51  scorptoxin      dynamic         50.0       dynamicX            1
# 53  scorptoxin      dynamic         30.0       dynamicX            1
# 55  scorptoxin      dynamic         10.0       dynamicX            1
# 56  scorptoxin   regressive         50.0            NaN          NaN
# 57  scorptoxin   regressive         30.0            NaN          NaN
# 58  scorptoxin   regressive         10.0            NaN          NaN
# 59  scorptoxin  progressive          NaN            NaN          NaN
# 61       ghf11      dynamic         50.0       dynamicX            1
# 63       ghf11      dynamic         30.0       dynamicX            1
# 65       ghf11      dynamic         10.0       dynamicX            1
# 66       ghf11   regressive         50.0            NaN          NaN
# 67       ghf11   regressive         30.0            NaN          NaN
# 68       ghf11   regressive         10.0            NaN          NaN
# 69       ghf11  progressive          NaN            NaN          NaN
# 71       toxin      dynamic         50.0       dynamicX            1
# 73       toxin      dynamic         30.0       dynamicX            1
# 75       toxin      dynamic         10.0       dynamicX            1
# 76       toxin   regressive         50.0            NaN          NaN
# 77       toxin   regressive         30.0            NaN          NaN
# 78       toxin   regressive         10.0            NaN          NaN
# 79       toxin  progressive          NaN            NaN          NaN
#
#      master_msa  ...        task    subset n_sequences mean_length min_length  \
# 1     famsa_msa  ...  alignments  combined          93   43.634409         34
# 3   tcoffee_msa  ...  alignments  combined          93   43.634409         34
# 5   tcoffee_msa  ...  alignments  combined          93   43.634409         34
# 6         FAMSA  ...  alignments  combined          93   43.634409         34
# 7         FAMSA  ...  alignments  combined          93   43.634409         34
# 8         FAMSA  ...  alignments  combined          93   43.634409         34
# 9         FAMSA  ...  alignments  combined          93   43.634409         34
# 11    famsa_msa  ...  alignments  combined         556  119.902878         33
# 13  tcoffee_msa  ...  alignments  combined         556  119.902878         33
# 15  tcoffee_msa  ...  alignments  combined         556  119.902878         33
# 16        FAMSA  ...  alignments  combined         556  119.902878         33
# 17        FAMSA  ...  alignments  combined         556  119.902878         33
# 18        FAMSA  ...  alignments  combined         556  119.902878         33
# 19        FAMSA  ...  alignments  combined         556  119.902878         33
# 21    famsa_msa  ...  alignments  combined         613  165.383361         32
# 23  tcoffee_msa  ...  alignments  combined         613  165.383361         32
# 25  tcoffee_msa  ...  alignments  combined         613  165.383361         32
# 26        FAMSA  ...  alignments  combined         613  165.383361         32
# 27        FAMSA  ...  alignments  combined         613  165.383361         32
# 28        FAMSA  ...  alignments  combined         613  165.383361         32
# 29        FAMSA  ...  alignments  combined         613  165.383361         32
# 31    famsa_msa  ...  alignments  combined         167   66.209581         54
# 33  tcoffee_msa  ...  alignments  combined         167   66.209581         54
# 35  tcoffee_msa  ...  alignments  combined         167   66.209581         54
# 36        FAMSA  ...  alignments  combined         167   66.209581         54
# 37        FAMSA  ...  alignments  combined         167   66.209581         54
# 38        FAMSA  ...  alignments  combined         167   66.209581         54
# 39        FAMSA  ...  alignments  combined         167   66.209581         54
# 41    famsa_msa  ...  alignments  combined         498  120.072289         62
# 43  tcoffee_msa  ...  alignments  combined         498  120.072289         62
# 45  tcoffee_msa  ...  alignments  combined         498  120.072289         62
# 46        FAMSA  ...  alignments  combined         498  120.072289         62
# 47        FAMSA  ...  alignments  combined         498  120.072289         62
# 48        FAMSA  ...  alignments  combined         498  120.072289         62
# 49        FAMSA  ...  alignments  combined         498  120.072289         62
# 51    famsa_msa  ...  alignments  combined         363   53.256198         22
# 53  tcoffee_msa  ...  alignments  combined         363   53.256198         22
# 55  tcoffee_msa  ...  alignments  combined         363   53.256198         22
# 56        FAMSA  ...  alignments  combined         363   53.256198         22
# 57        FAMSA  ...  alignments  combined         363   53.256198         22
# 58        FAMSA  ...  alignments  combined         363   53.256198         22
# 59        FAMSA  ...  alignments  combined         363   53.256198         22
# 61    famsa_msa  ...  alignments  combined         521  167.758157         26
# 63  tcoffee_msa  ...  alignments  combined         521  167.758157         26
# 65  tcoffee_msa  ...  alignments  combined         521  167.758157         26
# 66        FAMSA  ...  alignments  combined         521  167.758157         26
# 67        FAMSA  ...  alignments  combined         521  167.758157         26
# 68        FAMSA  ...  alignments  combined         521  167.758157         26
# 69        FAMSA  ...  alignments  combined         521  167.758157         26
# 71    famsa_msa  ...  alignments  combined         508   62.311024         30
# 73  tcoffee_msa  ...  alignments  combined         508   62.311024         30
# 75  tcoffee_msa  ...  alignments  combined         508   62.311024         30
# 76        FAMSA  ...  alignments  combined         508   62.311024         30
# 77        FAMSA  ...  alignments  combined         508   62.311024         30
# 78        FAMSA  ...  alignments  combined         508   62.311024         30
# 79        FAMSA  ...  alignments  combined         508   62.311024         30
#
#     max_length        file  size_group  perc_ref_total  method_extended
# 1           50    seatoxin       small        5.376344     dynamic_50.0
# 3           50    seatoxin       small        5.376344     dynamic_30.0
# 5           50    seatoxin       small        5.376344     dynamic_10.0
# 6           50    seatoxin       small        5.376344  regressive_50.0
# 7           50    seatoxin       small        5.376344  regressive_30.0
# 8           50    seatoxin       small        5.376344  regressive_10.0
# 9           50    seatoxin       small        5.376344  progressive_nan
# 11         163         TNF       small        0.899281     dynamic_50.0
# 13         163         TNF       small        0.899281     dynamic_30.0
# 15         163         TNF       small        0.899281     dynamic_10.0
# 16         163         TNF       small        0.899281  regressive_50.0
# 17         163         TNF       small        0.899281  regressive_30.0
# 18         163         TNF       small        0.899281  regressive_10.0
# 19         163         TNF       small        0.899281  progressive_nan
# 21         193         sti       small        0.815661     dynamic_50.0
# 23         193         sti       small        0.815661     dynamic_30.0
# 25         193         sti       small        0.815661     dynamic_10.0
# 26         193         sti       small        0.815661  regressive_50.0
# 27         193         sti       small        0.815661  regressive_30.0
# 28         193         sti       small        0.815661  regressive_10.0
# 29         193         sti       small        0.815661  progressive_nan
# 31          85         hip       small        2.994012     dynamic_50.0
# 33          85         hip       small        2.994012     dynamic_30.0
# 35          85         hip       small        2.994012     dynamic_10.0
# 36          85         hip       small        2.994012  regressive_50.0
# 37          85         hip       small        2.994012  regressive_30.0
# 38          85         hip       small        2.994012  regressive_10.0
# 39          85         hip       small        2.994012  progressive_nan
# 41         140    rnasemam       small        1.204819     dynamic_50.0
# 43         140    rnasemam       small        1.204819     dynamic_30.0
# 45         140    rnasemam       small        1.204819     dynamic_10.0
# 46         140    rnasemam       small        1.204819  regressive_50.0
# 47         140    rnasemam       small        1.204819  regressive_30.0
# 48         140    rnasemam       small        1.204819  regressive_10.0
# 49         140    rnasemam       small        1.204819  progressive_nan
# 51          69  scorptoxin       small        2.203857     dynamic_50.0
# 53          69  scorptoxin       small        2.203857     dynamic_30.0
# 55          69  scorptoxin       small        2.203857     dynamic_10.0
# 56          69  scorptoxin       small        2.203857  regressive_50.0
# 57          69  scorptoxin       small        2.203857  regressive_30.0
# 58          69  scorptoxin       small        2.203857  regressive_10.0
# 59          69  scorptoxin       small        2.203857  progressive_nan
# 61         227       ghf11       small        0.959693     dynamic_50.0
# 63         227       ghf11       small        0.959693     dynamic_30.0
# 65         227       ghf11       small        0.959693     dynamic_10.0
# 66         227       ghf11       small        0.959693  regressive_50.0
# 67         227       ghf11       small        0.959693  regressive_30.0
# 68         227       ghf11       small        0.959693  regressive_10.0
# 69         227       ghf11       small        0.959693  progressive_nan
# 71          77       toxin       small        3.937008     dynamic_50.0
# 73          77       toxin       small        3.937008     dynamic_30.0
# 75          77       toxin       small        3.937008     dynamic_10.0
# 76          77       toxin       small        3.937008  regressive_50.0
# 77          77       toxin       small        3.937008  regressive_30.0
# 78          77       toxin       small        3.937008  regressive_10.0
# 79          77       toxin       small        3.937008  progressive_nan
#
# [56 rows x 40 columns]

# %%
# 1 - Does the dynamic improve accuracy ? 
# a. plot all 3 metrics (SUM etc) vs the number of sequences (Dynamic + Regressive on FAMSA)
sns.set_context("talk")
metrics = [["sp", "sum of pairs"], ["tc", "total column"], ["column", "column"]]

for metric in metrics:
    f, ax = plt.subplots(figsize=(12, 7))
    sns.scatterplot(data=stats_alignments, y=metric[0], x="n_sequences", hue="method_extended",
                    palette = "magma",style = "benchmarking_dataset", s = 150)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel=metric[1], xlabel='number of sequences')

# %%
# 2 - At which computational loss? 
# b. plot all 3 metrics (SUM etc) vs the CPU time (aligner only) (Dynamic + Regressive on FAMSA)
for metric in metrics:
    f, ax = plt.subplots(figsize=(12, 7))
    sns.scatterplot(data=stats_alignments, y=metric[0], x="realtime", hue="method_extended",
                    palette = "magma",style = "benchmarking_dataset", s = 100)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set(ylabel=metric[1], xlabel='CPU time (ms)')

# %%
# c. plot all 3 metrics (SUM etc) vs the CPU time (aligner only AND aligner + extract + prediction) (Dynamic + Regressive on FAMSA)
