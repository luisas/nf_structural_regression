# %% [markdown]
# # REFERENCE - benchmark structural regression

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import matplotlib.ticker as ticker
import matplotlib as mpl
import sys
from math import *
from scipy.stats import binned_statistic
import inspect
from Bio import SeqIO
from pathlib import Path
sns.set_theme(style="white", context="talk")
import glob
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import itertools


from utils_benchmark import * 
#test()

sns.set_context("talk")


def get_stats(scores_df, summary_homfam_exthomfam):
    stats_alignments = pd.merge(scores_df, summary_homfam_exthomfam, on =["family","benchmarking_dataset"])
    stats_alignments["approach"] = stats_alignments[["method", "bucket_size", "master_msa", "slave_msa", "dynamicX_val", "align_method", "tree_method"]].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)
    stats_alignments["approach"] = stats_alignments.approach.apply(lambda val: val.replace("_nan",""))
    stats_alignments["fam_approach"] = stats_alignments["family"]+"_"+stats_alignments["approach"]
    stats_alignments.tc = pd.to_numeric(stats_alignments.tc)
    return(stats_alignments)
# Create an array with the colors you want to use
colors = ["grey", "#E13A3A"]
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))

# %%
evaluation_dir = "/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/"
outdir = "../../../data/structural_regression/plots/02_benchmarkCPU/"
seqs_dir = "/home/luisasantus/Desktop/crg_cluster/data/structural_regression/homfam/refs/"
# Load reference stats 
stats_alignments_ref= pd.read_csv(os.path.join("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/", "stats_alignments_refs.csv"))
summary_homfam_merged_tosave = pd.read_csv(os.path.join("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/", "02_summary_homfam_with_refs.csv"))

# Extract AF2 info for references only # Load AF2 scores
af2 = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/02_summary_af2.csv")
# Load datasets informations (Homfam + extHomfam)
summary_homfam_exthomfam = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/01_summary_homfam_exthomfam.csv")
summary_homfam_exthomfam = summary_homfam_exthomfam.rename(columns={"dataset": "benchmarking_dataset"})

# %%
# Extract all sequences in reference 
summary_ref_af2 = pd.DataFrame()
for f in listdir(seqs_dir):
     if f.endswith("fa"):
        fasta_sequences = SeqIO.parse(open(os.path.join(seqs_dir,f)),'fasta')
        for fasta in fasta_sequences:
            seq_id = [fasta.id.replace("/","_")]
            l = len(fasta.seq.replace("-", ""))
            entry = pd.DataFrame({'sequence': seq_id,"length":l, "name": [f.replace("-ref.fa","").strip()]})
            summary_ref_af2 =  pd.concat([summary_ref_af2, entry], ignore_index = True)
summary_ref_af2["subset"] = "ref"
summary_ref_af2["family"] = summary_ref_af2.name
summary_ref_af2 = summary_ref_af2.merge(af2, on = ["sequence", "family"])
af2_homfam_summary = summary_ref_af2.groupby(['family',"benchmarking_dataset"]).agg({'plddt': ['mean', 'min', 'max']}).reset_index().set_axis(["family", "benchmarking_dataset", "plddt_mean", "plddt_min", "plddt_max"], axis=1)

summary_homfam_merged_tosave["family"] = summary_homfam_merged_tosave.familcombined
summary_ref = pd.merge(summary_homfam_merged_tosave,af2_homfam_summary)

# %% [markdown]
# # plddt of ALL reference seqs

# %%
sns.set_theme(style="ticks")
sns.set_context("talk")


ax = sns.jointplot(
    data=summary_ref_af2,  fill=True, color = "royalblue", legend = False, 
    x="plddt", y="length",
    kind="kde"
)

nobs = summary_ref_af2['sequence'].value_counts().sum()

# Add it to the plot
#ax.fig.text(1,1,nobs,horizontalalignment='center',size='small',color='red')
ax.fig.suptitle("n="+str(nobs))
# Out:
# Text(0.5, 0.98, 'n=772')

# %% [markdown]
# # Load references MSAs

# %%
# Define dataset 
dataset = "homfam"
scores_dir = join("/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/",dataset,"evaluation/score/")

scores = pd.DataFrame()
for score_name in os.listdir(scores_dir):
    score_file = os.path.join(scores_dir,score_name)
    # Parse file
    if score_file.endswith(".scores"):
        # only keep references
        if "-ref" in score_file:
            score_df = pd.read_csv(score_file,sep = ";", header = None).drop(4, axis = 1)
            scores = pd.concat([scores, score_df])
scores = scores.iloc[:,0:4]
scores.columns = ['name', 'sp', 'tc', 'column']

# %% [markdown]
# # Extract subsets of interest

# %%
# -------------------------
#      Regressive
# -------------------------
regressive_scores = scores[scores.name.str.contains("regressive")]
regressive_scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = regressive_scores.name.str.split(".", expand = True)

# -------------------------
#      Progressive
# -------------------------
progressive_scores = scores[scores.name.str.contains("progressive")]
progressive_scores[["family", "method", "align_method", "tree_method"]] = progressive_scores.name.str.split(".", expand = True)

# -------------------------
#      Dyanmic
# -------------------------
dynamic_scores = scores[scores.name.str.contains("dynamic")]
dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)


# --------------   summary all -----------------
scores_df = pd.concat([regressive_scores, progressive_scores, dynamic_scores], ignore_index=True, sort=False)

scores_df.family = scores_df.family.str.replace("-ref","")
scores_df["benchmarking_dataset"] = dataset

stats_alignments_ref = get_stats(scores_df, summary_homfam_exthomfam)

df = stats_alignments_ref
df.nref = df.n_sequences * df.perc_ref_total /100 

df = pd.merge(df, summary_ref, on = "family")
# Out:
# /tmp/ipykernel_49400/3451490122.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regressive_scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = regressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regressive_scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = regressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regressive_scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = regressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regressive_scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = regressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regressive_scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = regressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   progressive_scores[["family", "method", "align_method", "tree_method"]] = progressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   progressive_scores[["family", "method", "align_method", "tree_method"]] = progressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   progressive_scores[["family", "method", "align_method", "tree_method"]] = progressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   progressive_scores[["family", "method", "align_method", "tree_method"]] = progressive_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dynamic_scores[["family", "method", "bucket_size", "dynamicX_label","dynamicX_val","master_msa", "slave_msa", "tree_method"]] = dynamic_scores.name.str.split(".", expand = True)
# /tmp/ipykernel_49400/3451490122.py:29: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.nref = df.n_sequences * df.perc_ref_total /100

# %%
scores_df
# Out:
#                                                    name    sp    tc  column  \
# 0            cryst-ref.regressive.50.FAMSA.FAMSA-medoid  63.8   1.7     0.8
# 1     scorptoxin-ref.regressive.1000.FAMSA.FAMSA-medoid  95.4  86.3    90.0
# 2            KAS-ref.regressive.1000.FAMSA.FAMSA-medoid  88.2  72.2    77.0
# 3          lyase-1-ref.regressive.50.FAMSA.FAMSA-medoid  77.5  59.4    59.9
# 4            hom-ref.regressive.1000.FAMSA.FAMSA-medoid  98.1  79.7    95.3
# ...                                                 ...   ...   ...     ...
# 1252  tms-ref.dynamic.50.dynamicX.1000.famsa_msa.fam...  96.3  85.6    91.5
# 1253  ricin-ref.dynamic.50.dynamicX.1.famsa_msa.fams...  91.8  77.3    84.9
# 1254  ltn-ref.dynamic.50.dynamicX.1000.famsa_msa.fam...  94.3  72.7    80.2
# 1255  ricin-ref.dynamic.50.dynamicX.1000.famsa_msa.f...  91.8  77.3    84.9
# 1256  egf-ref.dynamic.50.dynamicX.100000000.famsa_ms...  75.3  51.5    47.9
#
#           family      method bucket_size align_method   tree_method  \
# 0          cryst  regressive          50        FAMSA  FAMSA-medoid
# 1     scorptoxin  regressive        1000        FAMSA  FAMSA-medoid
# 2            KAS  regressive        1000        FAMSA  FAMSA-medoid
# 3        lyase-1  regressive          50        FAMSA  FAMSA-medoid
# 4            hom  regressive        1000        FAMSA  FAMSA-medoid
# ...          ...         ...         ...          ...           ...
# 1252         tms     dynamic          50          NaN  FAMSA-medoid
# 1253       ricin     dynamic          50          NaN  FAMSA-medoid
# 1254         ltn     dynamic          50          NaN  FAMSA-medoid
# 1255       ricin     dynamic          50          NaN  FAMSA-medoid
# 1256         egf     dynamic          50          NaN  FAMSA-medoid
#
#      dynamicX_label dynamicX_val master_msa  slave_msa benchmarking_dataset
# 0               NaN          NaN        NaN        NaN               homfam
# 1               NaN          NaN        NaN        NaN               homfam
# 2               NaN          NaN        NaN        NaN               homfam
# 3               NaN          NaN        NaN        NaN               homfam
# 4               NaN          NaN        NaN        NaN               homfam
# ...             ...          ...        ...        ...                  ...
# 1252       dynamicX         1000  famsa_msa  famsa_msa               homfam
# 1253       dynamicX            1  famsa_msa  famsa_msa               homfam
# 1254       dynamicX         1000  famsa_msa  famsa_msa               homfam
# 1255       dynamicX         1000  famsa_msa  famsa_msa               homfam
# 1256       dynamicX    100000000  famsa_msa  famsa_msa               homfam
#
# [1257 rows x 14 columns]

# %%
# Comparison 1: DYNAMIC w/ 3D
df_dyn_3d = df[df.approach == "dynamic_50_tcoffee_msa_famsa_msa_100000000_FAMSA-medoid"]
#df_dyn_3d["nref"] = df_dyn_3d.n_sequences * df_dyn_3d.perc_ref_total /100 

# Comparison 2: DYNAMIC w/ FAMSA 
df_dyn_famsa = df[df.approach == "dynamic_50_famsa_msa_famsa_msa_100000000_FAMSA-medoid"]

# Comparison 3: PROGRESSIVE w/ 3D 
df_prog_3d = df[df.approach == "progressive_3DCOFFEE_FAMSA-medoid"]
df_prog_3d_mbed = df[df.approach == "progressive_3DCOFFEE_MBED"]

# Comparison 3: PROGRESSIVE w/ 3D 
df_prog_3d_probapair = df[df.approach == "progressive_PROBAPAIR_FAMSA-medoid"]
df_prog_3d_probapair_mbed = df[df.approach == "progressive_PROBAPAIR_MBED"]

# For sanity checks, MBED 
df_prog_3d_expresso = df[df.approach == "progressive_EXPRESSOREAL_MBED"]
df_prog_3dcoffee = df[df.approach == "progressive_3DCOFFEE_MBED"]
df_prog_famsa = df[df.approach == "progressive_FAMSA_MBED"]


# Comparison 4: PROGRESSIVE w/ FAMSA
df_prog_famsa_medoid = df[df.approach == "progressive_FAMSA_FAMSA-medoid"]

# %% [markdown]
# # BUG SANITY CHECK

# %% [markdown]
# #### Separate the exact classes we want the comparison with

# %%
df = pd.concat([df_dyn_3d, df_dyn_famsa, df_prog_3d, df_prog_famsa])

# %% [markdown]
# #### Do 3D progressive and 3D dyanmic give the same (aka --> any bug in dynamic --> NO)

# %%
# Do 3D progressive and 3D dyanmic give the same (aka --> any bug in dynamic --> NO)
df_dyn_3d_red = df_dyn_3d[["family","tc"]]
df_prog_3d_red = df_prog_3d[["family", "tc"]]
df_3d_all = pd.merge(df_dyn_3d_red, df_prog_3d_red, on = "family")
#np.array(df_3d_all.tc_x == df_3d_all.tc_y)

# %% [markdown]
# #### Do 3D COFFEE and 3D PROBAPAIR give the same?  no (aka --> WE ARE USING THE STRUCTURES)

# %%
# Do 3D COFFEE and 3D PROBAPAIR give the same?  no (aka --> WE ARE USING THE STRUCTURES)
df1_red = df_dyn_3d[["family","tc"]]
df2_red = df_prog_3d_probapair[["family", "tc"]]
df_all = pd.merge(df1_red, df2_red, on = "family")
#np.array(df_all.tc_x == df_all.tc_y)

# %%
# Do 3D progressive and 3D dyanmic give the same : we are using different trees options! 
# Take a decision on what to keep and mae it consistent!!
df_dyn_famsa_red = df_dyn_famsa[["family","tc"]]
df_prog_famsa_red = df_prog_famsa[["family", "tc"]]
df_famsa_all = pd.merge(df_dyn_famsa_red, df_prog_famsa_red, on = "family")
#np.array(df_famsa_all.tc_x ==df_famsa_all.tc_y)

# %% [markdown]
# # TC SANITY CHECK

# %% [markdown]
# ## With my approach I cannot retrieve the same templates

# %%
# Check which structures are getting used in Expresso 
templates = pd.DataFrame()
# Collect templates
for name in glob.glob('/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/homfam/structures/search_hits/mmseqs/*-ref/*/template.txt'):
    fam_name_complete= name.split("/")[-3]
    family = fam_name_complete.replace("-ref", "")
    template_df = pd.read_csv(name, sep = " ", header = None)
    ntemplate = len(template_df.index)
    new_row = pd.DataFrame({"family_complete":[fam_name_complete], "family": [family],'ntemplates':[ntemplate]})
    templates = pd.concat([templates,new_row])
# Per family check the number of structures in template
# pd.merge(summary_ref,templates, on  = "family")[["family", "n_sequences_ref", "ntemplates"]]

# %%
df_expresso_famsa = pd.merge(df_prog_3d_expresso, df_prog_famsa, on = ["family"] )
df_dynamic_famsa = pd.merge(df_dyn_3d,df_prog_famsa, on = ["family"] )
df_dynamic_famsa = df_dynamic_famsa[df_dynamic_famsa.family.isin(list(df_expresso_famsa.family))]
expresso_less_famsa = list(df_expresso_famsa[df_expresso_famsa.sp_x < df_expresso_famsa.sp_y ]["family"])
dynamic_less_famsa = list(df_dynamic_famsa[df_dynamic_famsa.sp_x < df_dynamic_famsa.sp_y ]["family"])
set1 = set(expresso_less_famsa)
set2 = set(dynamic_less_famsa)
venn2([set1, set2], ('expresso<famsa', '3D+AF2<famsa'))
plt.show()

# %%
## Hypothesis one: expresso with PDB should be higher than famsa
## Also i could check if families where we do worse with structures, whether its AF2 or is the structural alignment

df_d_r = pd.merge(df_prog_3dcoffee, df_prog_famsa, on = ["family"] )
df_d_r["diff_tc"] = df_d_r.tc_x - df_d_r.tc_y 
df_d_r["diff_sp"] = df_d_r.sp_x - df_d_r.sp_y 
df_d_r["perc_change_tc"]= df_d_r.diff_tc *100/ abs(df_d_r.tc_y) 

# Set up the matplotlib figure
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(15, 5), sharex=True)

# Center the data to make it diverging
sns.barplot(x=df_d_r.diff_tc, y=df_d_r.diff_tc, color ="grey", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set(ylabel="EXPRESSO TC - not structure TC", xlabel = "", xticklabels="")

# Center the data to make it diverging
sns.barplot(x=df_d_r.diff_sp, y=df_d_r.diff_sp, color ="grey", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set(ylabel="3D+AF2 SP - FAMSA", xlabel = "", xticklabels="")
# Out:
# [Text(0, 0.5, '3D+AF2 SP - FAMSA'),
#  Text(0.5, 0, ''),
#  [Text(0, 0, ''),
#   Text(1, 0, ''),
#   Text(2, 0, ''),
#   Text(3, 0, ''),
#   Text(4, 0, ''),
#   Text(5, 0, ''),
#   Text(6, 0, ''),
#   Text(7, 0, ''),
#   Text(8, 0, ''),
#   Text(9, 0, ''),
#   Text(10, 0, ''),
#   Text(11, 0, ''),
#   Text(12, 0, ''),
#   Text(13, 0, ''),
#   Text(14, 0, ''),
#   Text(15, 0, ''),
#   Text(16, 0, ''),
#   Text(17, 0, ''),
#   Text(18, 0, ''),
#   Text(19, 0, ''),
#   Text(20, 0, ''),
#   Text(21, 0, ''),
#   Text(22, 0, ''),
#   Text(23, 0, ''),
#   Text(24, 0, ''),
#   Text(25, 0, ''),
#   Text(26, 0, ''),
#   Text(27, 0, ''),
#   Text(28, 0, ''),
#   Text(29, 0, ''),
#   Text(30, 0, ''),
#   Text(31, 0, ''),
#   Text(32, 0, ''),
#   Text(33, 0, ''),
#   Text(34, 0, ''),
#   Text(35, 0, ''),
#   Text(36, 0, ''),
#   Text(37, 0, ''),
#   Text(38, 0, ''),
#   Text(39, 0, ''),
#   Text(40, 0, ''),
#   Text(41, 0, ''),
#   Text(42, 0, ''),
#   Text(43, 0, ''),
#   Text(44, 0, ''),
#   Text(45, 0, ''),
#   Text(46, 0, ''),
#   Text(47, 0, ''),
#   Text(48, 0, ''),
#   Text(49, 0, ''),
#   Text(50, 0, ''),
#   Text(51, 0, ''),
#   Text(52, 0, ''),
#   Text(53, 0, ''),
#   Text(54, 0, ''),
#   Text(55, 0, ''),
#   Text(56, 0, ''),
#   Text(57, 0, ''),
#   Text(58, 0, ''),
#   Text(59, 0, ''),
#   Text(60, 0, ''),
#   Text(61, 0, ''),
#   Text(62, 0, ''),
#   Text(63, 0, ''),
#   Text(64, 0, ''),
#   Text(65, 0, ''),
#   Text(66, 0, ''),
#   Text(67, 0, ''),
#   Text(68, 0, ''),
#   Text(69, 0, ''),
#   Text(70, 0, ''),
#   Text(71, 0, ''),
#   Text(72, 0, ''),
#   Text(73, 0, ''),
#   Text(74, 0, ''),
#   Text(75, 0, ''),
#   Text(76, 0, ''),
#   Text(77, 0, ''),
#   Text(78, 0, '')]]

# %% [markdown]
# ### Exploration - why could that happen?

# %%
# Which are the ones for which we do not get ? 
family_worst = list(df_d_r[df_d_r.diff_tc < 0].family)
df_d_r["diff_qualitatively"] = "better"
df_d_r.loc[df_d_r.diff_tc < 0, 'diff_qualitatively'] = "worst"
df_d_r.diff_qualitatively.value_counts()

sns.violinplot(data = df_d_r, y = "plddt_mean_x", x = "diff_qualitatively")
sns.displot(df_d_r, x = "n_sequences_x", hue = "diff_qualitatively", kind = "kde")
sns.boxplot(data = df_d_r, y = "n_sequences_x", x = "diff_qualitatively")
# Out:
# <AxesSubplot:xlabel='diff_qualitatively', ylabel='n_sequences_x'>

# %%
# Create an array with the colors you want to use
colors = ["grey", "#E13A3A"]
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))
sns.scatterplot(data = df_d_r, x = "perc_change_tc", y = "tc_y", hue = "diff_qualitatively").set(ylabel = "tc (no structure)", xlabel = "% change tc scores")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


# Create an array with the colors you want to use
colors = ["grey", "#E13A3A"]
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))
sns.scatterplot(data = df_d_r, x = "mean_length_x", y = "plddt_mean_x", hue = "diff_qualitatively")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


# Create an array with the colors you want to use
colors = ["grey", "#E13A3A"]
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))
sns.scatterplot(data = df_d_r, y = "tc_x", x = "n_sequences_x", hue = "diff_qualitatively").set(xlabel  ="n_sequences in family", ylabel = "tc score")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_d_r.columns
# Out:
# Index(['name_x', 'sp_x', 'tc_x', 'column_x', 'family', 'method_x',
#        'bucket_size_x', 'align_method_x', 'tree_method_x', 'dynamicX_label_x',
#        'dynamicX_val_x', 'master_msa_x', 'slave_msa_x',
#        'benchmarking_dataset_x_x', 'subset_x', 'n_sequences_x',
#        'mean_length_x', 'min_length_x', 'max_length_x', 'file_x',
#        'size_group_x', 'perc_ref_total_x_x', 'approach_x', 'fam_approach_x',
#        'familcombined_x', 'subset_ref_x', 'n_sequences_ref_x',
#        'mean_length_ref_x', 'min_length_ref_x', 'maref_length_ref_x',
#        'file_ref_x', 'subset_combined_x', 'n_sequences_combined_x',
#        'mean_length_combined_x', 'min_length_combined_x',
#        'maref_length_combined_x', 'file_combined_x', 'perc_ref_total_y_x',
#        'benchmarking_dataset_y_x', 'plddt_mean_x', 'plddt_min_x',
#        'plddt_max_x', 'name_y', 'sp_y', 'tc_y', 'column_y', 'method_y',
#        'bucket_size_y', 'align_method_y', 'tree_method_y', 'dynamicX_label_y',
#        'dynamicX_val_y', 'master_msa_y', 'slave_msa_y',
#        'benchmarking_dataset_x_y', 'subset_y', 'n_sequences_y',
#        'mean_length_y', 'min_length_y', 'max_length_y', 'file_y',
#        'size_group_y', 'perc_ref_total_x_y', 'approach_y', 'fam_approach_y',
#        'familcombined_y', 'subset_ref_y', 'n_sequences_ref_y',
#        'mean_length_ref_y', 'min_length_ref_y', 'maref_length_ref_y',
#        'file_ref_y', 'subset_combined_y', 'n_sequences_combined_y',
#        'mean_length_combined_y', 'min_length_combined_y',
#        'maref_length_combined_y', 'file_combined_y', 'perc_ref_total_y_y',
#        'benchmarking_dataset_y_y', 'plddt_mean_y', 'plddt_min_y',
#        'plddt_max_y', 'diff_tc', 'diff_sp', 'perc_change_tc',
#        'diff_qualitatively'],
#       dtype='object')

# %% [markdown]
# # General metrics exploration

# %% [markdown]
# ## Load % identity and TCS

# %%
# ---------------------------------------------------------
# Get SIMILARITY per family 
# Get number of sequences per family (and store for future notebooks)
# ---------------------------------------------------------

sims = os.path.join(evaluation_dir,"homfam/evaluation/sim/*.sim")
sim_df = pd.DataFrame()

for file in list(glob.glob(sims)):
    full_name = file.split(sep = "/")[-1].replace(".sim", "")
    file_opened = open(file, "r")
    tot_line = [line.split() for line in file_opened if line.startswith('TOT')]
    entry = pd.DataFrame({'name': [full_name],"sim_tot": tot_line[0][3]})
    sim_df =  pd.concat([sim_df, entry], ignore_index = True)

# ---------------------------------------------------------
# Get TCS (and store for future notebooks) 
# ---------------------------------------------------------

tcss = os.path.join(evaluation_dir,"homfam/evaluation/tcs/*.tcs")
tcss_3d = os.path.join(evaluation_dir,"homfam/alignments/*/*/*.tcs")
tcs_paths = list(glob.glob(tcss)) + list(glob.glob(tcss_3d))
tcs_df = pd.DataFrame()

for file in tcs_paths:
    full_name = file.split(sep = "/")[-1].replace(".tcs", "")
    file_opened = open(file, "r")
    tot_line = [line.split(sep = "=") for line in file_opened if line.startswith('SCORE')]
    entry = pd.DataFrame({'name': [full_name],"tcs_tot": tot_line[0][1].strip()})
    tcs_df =  pd.concat([tcs_df, entry], ignore_index = True)

# %%
tcs_df
# Out:
#                                    name tcs_tot
# 0        aat-ref.progressive.FAMSA.MBED     721
# 1    annexin-ref.progressive.FAMSA.MBED     997
# 2       blmb-ref.progressive.FAMSA.MBED     545
# 3        uce-ref.progressive.FAMSA.MBED     861
# 4    lyase_1-ref.progressive.FAMSA.MBED     717
# ..                                  ...     ...
# 183   asp-ref.progressive.3DCOFFEE.MBED     985
# 184   GEL-ref.progressive.3DCOFFEE.MBED     991
# 185   HLH-ref.progressive.3DCOFFEE.MBED     972
# 186   hip-ref.progressive.3DCOFFEE.MBED     981
# 187  p450-ref.progressive.3DCOFFEE.MBED     926
#
# [188 rows x 2 columns]

# %%
# Add stats
df_prog_famsa_stats = pd.merge(df_prog_famsa,sim_df, on = "name")
df_prog_famsa_stats = pd.merge(df_prog_famsa_stats,tcs_df, on = "name")

df_prog_3dcoffee_stats = pd.merge(df_prog_3dcoffee,sim_df, on = "name")
df_prog_3dcoffee_stats = pd.merge(df_prog_3dcoffee_stats,tcs_df, on = "name")

# %%
df_d_r = pd.merge(df_prog_3dcoffee_stats, df_prog_famsa_stats, on = ["family"] )
df_d_r["diff_tc"] = df_d_r.tc_x - df_d_r.tc_y 
df_d_r["diff_sp"] = df_d_r.sp_x - df_d_r.sp_y 
df_d_r["perc_change_tc"]= df_d_r.diff_tc *100/ abs(df_d_r.tc_y)
df_d_r["perc_change_sp"]= df_d_r.diff_sp *100/ abs(df_d_r.sp_y)

df_d_r.columns = [c.replace("_x", "_3D") for c in list(df_d_r.columns)]
df_d_r.columns = [c.replace("_y", "_FAMSA") for c in list(df_d_r.columns)]

df_d_r["diff_qualitatively"] = "better"
df_d_r.loc[df_d_r.perc_change_sp < 0, 'diff_qualitatively'] = "worst "
df_d_r.loc[df_d_r.perc_change_sp < -10, 'diff_qualitatively'] = "worst -10 "

df_d_r["tcs_tot_3D"]= df_d_r["tcs_tot_3D"].astype('int')
df_d_r["sim_tot_3D"]= df_d_r["sim_tot_3D"].astype('float')
df_d_r["tcs_tot_FAMSA"]= df_d_r["tcs_tot_FAMSA"].astype('int')
df_d_r["sim_tot_FAMSA"]= df_d_r["sim_tot_FAMSA"].astype('float')

# %%
df_correlation = df_d_r[["diff_tc","tc_3D","tc_FAMSA","sp_3D","sp_FAMSA", "mean_length_3D", "plddt_min_3D", "plddt_mean_3D", "sim_tot_3D", "tcs_tot_3D", "sim_tot_FAMSA", "tcs_tot_FAMSA", "perc_change_sp"]]

#df_correlation.columns = ["diff_tc", "tc_structure", "tc_nostructure", "n_sequences_family", "mean_length", "plddt_mean"]
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests
def get_correlations(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how="outer")
    correlations = dfcols.transpose().join(dfcols, how="outer")
    for ix, r in enumerate(df.columns):
        for jx, c in enumerate(df.columns):
            sp = spearmanr(df[r], df[c])
            correlations[c][r] = sp[0]
            pvalues[c][r] = sp[1] if ix > jx else np.nan  # Only store values below the diagonal
    return correlations.astype("float"), pvalues.astype("float")


correlations, uncorrected_p_values = get_correlations(df_correlation)

# Correct p-values for multiple testing and check significance (True if the corrected p-value < 0.05)
shape = uncorrected_p_values.values.shape
significant_matrix = multipletests(uncorrected_p_values.values.flatten())[0].reshape(
    shape
)

# Here we start plotting
g = sns.clustermap(correlations, cmap="vlag", vmin=-1, vmax=1)

# Here labels on the y-axis are rotated
for tick in g.ax_heatmap.get_yticklabels():
    tick.set_rotation(0)

# Here we add asterisks onto cells with signficant correlations
for i, ix in enumerate(g.dendrogram_row.reordered_ind):
    for j, jx in enumerate(g.dendrogram_row.reordered_ind):
        if i != j:
            text = g.ax_heatmap.text(
                j + 0.5,
                i + 0.5,
                "*" if significant_matrix[ix, jx] or significant_matrix[jx, ix] else "",
                ha="center",
                va="center",
                color="black",
            )
            text.set_fontsize(20)

# Save a high-res copy of the image to disk
plt.tight_layout()
plt.savefig("clustermap.png", dpi=200)

# %% [markdown]
# ## Extract GDT_TS

# %%
gdt_summary = pd.DataFrame()
for file in glob.glob("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/homfam/pdbs/structures/eval_gdt/*/*.txt"):
    gdt = pd.read_csv(file, header = None)
    gdt_summary = pd.concat([gdt_summary, gdt])
gdt_summary.rename(index={0: "family", 1: "sequence", 2: "metric", 3: "value"})

# %%
gdtss = gdt_summary[gdt_summary[2] == "GDT-TS"]

# %%
af2_homfam_summary = af2_homfam.groupby(['family',"benchmarking_dataset"]).agg({'plddt': ['mean', 'min', 'max']}).reset_index().set_axis(["family", "benchmarking_dataset", "plddt_mean", "plddt_min", "plddt_max"], axis=1)
# Out:
#           0      1       2       3
# 2  seatoxin   1ahl  GDT-TS  0.7653
# 2  seatoxin   1sh1  GDT-TS  0.7865
# 2  seatoxin   1bds  GDT-TS  0.8256
# 2  seatoxin   1apf  GDT-TS  0.7449
# 2  seatoxin   1atx  GDT-TS  0.8207
# 2       hip  3hipa  GDT-TS  0.0000
# 2       hip  2hipa  GDT-TS  0.9754
# 2       hip  1isua  GDT-TS  1.0000
# 2       hip  1ckua  GDT-TS  0.9824
# 2       hip   1hpi  GDT-TS  0.9965

# %% [markdown]
# ### Check general expectations

# %%
x_vars = ["sim_tot_3D", "tcs_tot_3D","plddt_max_3D"]
y_vars = ["sp_3D", "tc_3D"]
assay_combos = list(itertools.product(x_vars, y_vars))

# %%
df_d_r
# Out:
#                                         name_3D  sp_3D  tc_3D  column_3D  \
# 0           cryst-ref.progressive.3DCOFFEE.MBED   87.8   56.4       58.2
# 1      scorptoxin-ref.progressive.3DCOFFEE.MBED   95.1   79.5       85.6
# 2             KAS-ref.progressive.3DCOFFEE.MBED   94.5   85.2       89.8
# 3             hom-ref.progressive.3DCOFFEE.MBED   98.5   81.2       97.1
# 4            p450-ref.progressive.3DCOFFEE.MBED   84.1   47.1       60.9
# ..                                          ...    ...    ...        ...
# 89    hormone_rec-ref.progressive.3DCOFFEE.MBED   82.8   55.5       70.7
# 90            il8-ref.progressive.3DCOFFEE.MBED   94.2   64.9       75.2
# 91  DMRL_synthase-ref.progressive.3DCOFFEE.MBED   93.4   73.4       81.0
# 92  biotin_lipoyl-ref.progressive.3DCOFFEE.MBED   95.4   81.2       86.1
# 93          ricin-ref.progressive.3DCOFFEE.MBED   94.8   85.0       90.1
#
#            family    method_3D bucket_size_3D align_method_3D tree_method_3D  \
# 0           cryst  progressive            NaN        3DCOFFEE           MBED
# 1      scorptoxin  progressive            NaN        3DCOFFEE           MBED
# 2             KAS  progressive            NaN        3DCOFFEE           MBED
# 3             hom  progressive            NaN        3DCOFFEE           MBED
# 4            p450  progressive            NaN        3DCOFFEE           MBED
# ..            ...          ...            ...             ...            ...
# 89    hormone_rec  progressive            NaN        3DCOFFEE           MBED
# 90            il8  progressive            NaN        3DCOFFEE           MBED
# 91  DMRL_synthase  progressive            NaN        3DCOFFEE           MBED
# 92  biotin_lipoyl  progressive            NaN        3DCOFFEE           MBED
# 93          ricin  progressive            NaN        3DCOFFEE           MBED
#
#    dynamicX_label_3D  ... plddt_mean_FAMSA plddt_min_FAMSA plddt_max_FAMSA  \
# 0                NaN  ...        84.566829         80.5675         86.1308
# 1                NaN  ...        79.984238         77.3084         81.1569
# 2                NaN  ...        88.465667         87.9569         89.0181
# 3                NaN  ...        76.367875         71.7398         81.2337
# 4                NaN  ...        87.348567         84.9591         89.7061
# ..               ...  ...              ...             ...             ...
# 89               NaN  ...        84.818700         80.0570         86.5378
# 90               NaN  ...        73.355964         67.9260         77.4029
# 91               NaN  ...        85.676480         84.7221         86.5815
# 92               NaN  ...        74.334729         70.6403         80.5796
# 93               NaN  ...        87.351771         85.3950         88.5306
#
#    sim_tot_FAMSA tcs_tot_FAMSA  diff_tc  diff_sp  perc_change_tc  \
# 0          48.35           666     54.7     24.0     3217.647059
# 1          46.90           828     -4.1      0.1       -4.904306
# 2          31.72           837     13.0      6.3       18.005540
# 3          34.60           843      1.5      0.4        1.882058
# 4          20.50           721     14.2     13.6       43.161094
# ..           ...           ...      ...      ...             ...
# 89         22.47           711     14.9     12.2       36.699507
# 90         33.41           770      1.3      1.0        2.044025
# 91         32.25           900      1.8      2.3        2.513966
# 92         29.39           885      0.0      0.1        0.000000
# 93         37.09           877      7.7      3.0        9.961190
#
#     perc_change_sp diff_qualitatively
# 0        37.617555             better
# 1         0.105263             better
# 2         7.142857             better
# 3         0.407747             better
# 4        19.290780             better
# ..             ...                ...
# 89       17.280453             better
# 90        1.072961             better
# 91        2.524698             better
# 92        0.104932             better
# 93        3.267974             better
#
# [94 rows x 92 columns]

# %%
assay_combos
# Out:
# [('sim_tot_3D', 'sp_3D'),
#  ('sim_tot_3D', 'tc_3D'),
#  ('tcs_tot_3D', 'sp_3D'),
#  ('tcs_tot_3D', 'tc_3D'),
#  ('plddt_max_3D', 'sp_3D'),
#  ('plddt_max_3D', 'tc_3D')]

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.set_context("talk")
fig, axes = plt.subplots(3, 2, figsize=(16,19))

def scatter_bench(x,y,i,j, legend = False):
    g = sns.scatterplot(ax=axes[i, j],data = df_d_r, x=x, y=y,  \
                        edgecolor = "grey", linewidth = 1, s = 40, legend = legend)
    g.set(ylim=(0,100))

    if(legend == True):
        g.legend(bbox_to_anchor=(0.7, 1.35), borderaxespad=0, fontsize='x-large')
    


assay = 0 
for i in range(0,3):
    for j in range (0,2): 
        scatter_bench(assay_combos[assay][0], assay_combos[assay][1], i,j)
        assay += 1

# %% [markdown]
# # Check for the families where we are doing worse

# %%
problematic_families = df_d_r[df_d_r.perc_change_sp < 0]

# %%
problematic_families
# Out:
#                                           name_3D  sp_3D  tc_3D  column_3D  \
# 6               HLH-ref.progressive.3DCOFFEE.MBED   89.2   78.6       77.4
# 19          HMG_box-ref.progressive.3DCOFFEE.MBED   96.7   85.2       93.9
# 21              int-ref.progressive.3DCOFFEE.MBED   88.0   72.8       77.1
# 24              ins-ref.progressive.3DCOFFEE.MBED   87.8   56.5       77.9
# 25              rhv-ref.progressive.3DCOFFEE.MBED   57.0   33.3       41.7
# 27  myb_DNA-binding-ref.progressive.3DCOFFEE.MBED   89.8   69.6       78.2
# 30               hr-ref.progressive.3DCOFFEE.MBED   98.9   93.7       97.7
# 32            ChtBD-ref.progressive.3DCOFFEE.MBED   97.3   88.4       90.8
# 38              mmp-ref.progressive.3DCOFFEE.MBED   97.6   89.9       93.9
#
#              family    method_3D bucket_size_3D align_method_3D  \
# 6               HLH  progressive            NaN        3DCOFFEE
# 19          HMG_box  progressive            NaN        3DCOFFEE
# 21              int  progressive            NaN        3DCOFFEE
# 24              ins  progressive            NaN        3DCOFFEE
# 25              rhv  progressive            NaN        3DCOFFEE
# 27  myb_DNA-binding  progressive            NaN        3DCOFFEE
# 30               hr  progressive            NaN        3DCOFFEE
# 32            ChtBD  progressive            NaN        3DCOFFEE
# 38              mmp  progressive            NaN        3DCOFFEE
#
#    tree_method_3D dynamicX_label_3D  ... plddt_mean_FAMSA plddt_min_FAMSA  \
# 6            MBED               NaN  ...        73.734340         62.6524
# 19           MBED               NaN  ...        75.899900         68.6329
# 21           MBED               NaN  ...        84.861620         83.8319
# 24           MBED               NaN  ...        66.639933         59.9665
# 25           MBED               NaN  ...        71.582433         69.6655
# 27           MBED               NaN  ...        73.745080         69.1797
# 30           MBED               NaN  ...        79.470240         73.0645
# 32           MBED               NaN  ...        72.533880         70.6585
# 38           MBED               NaN  ...        85.521800         84.3517
#
#    plddt_max_FAMSA sim_tot_FAMSA tcs_tot_FAMSA  diff_tc  diff_sp  \
# 6          80.1354         27.98           795     -5.9     -2.4
# 19         80.1560         24.69           822      0.0     -0.6
# 21         86.2072         22.02           722     -2.4     -2.9
# 24         75.7398         44.79           936    -20.3     -8.5
# 25         73.3991         33.28           837    -17.1    -21.6
# 27         76.7059         40.86           848    -14.3     -7.0
# 30         82.8730         53.31           990     -6.3     -1.1
# 32         76.0055         58.72           941     -2.3     -1.0
# 38         85.9889         55.05           970     -3.0     -0.8
#
#     perc_change_tc  perc_change_sp diff_qualitatively
# 6        -6.982249       -2.620087             worst
# 19        0.000000       -0.616650             worst
# 21       -3.191489       -3.190319             worst
# 24      -26.432292       -8.826584             worst
# 25      -33.928571      -27.480916         worst -10
# 27      -17.044100       -7.231405             worst
# 30       -6.300000       -1.100000             worst
# 32       -2.535832       -1.017294             worst
# 38       -3.229279       -0.813008             worst
#
# [9 rows x 92 columns]

# %%
sns.histplot(data=problematic_families, x="perc_change_sp", binwidth = 1)
# Out:
# <AxesSubplot:xlabel='perc_change_sp', ylabel='Count'>

# %%
# 1. Expectations: TCS vs SP
plt.figure(figsize=(6,4.8))

x_var = "perc_change_sp"
y_var = "sim_tot_3D"

vmin = min(df_d_r[hue_var])
vmax = max(df_d_r[hue_var])
max_hue = max(abs(vmin), abs(vmax))

sns.scatterplot(data = problematic_families, x = x_var, y = y_var, \
                edgecolor = "grey", linewidth = 1, \
                hue_norm=(-max_hue,max_hue), palette="vlag")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [235], in <cell line: 9>()
#       7 vmin = min(df_d_r[hue_var])
#       8 vmax = max(df_d_r[hue_var])
# ----> 9 max_hue = max(abs(vmin), abs(vmax))
#      11 sns.scatterplot(data = problematic_families, x = x_var, y = y_var, \
#      12                 edgecolor = "grey", linewidth = 1, \
#      13                 hue_norm=(-max_hue,max_hue), palette="vlag")
#
# TypeError: bad operand type for abs(): 'str'

# %% [markdown]
# # Extract the minimum TCS

# %%
# ---------------------------------------------------------
# Get TCS (and store for future notebooks) 
# ---------------------------------------------------------

tcss = os.path.join(evaluation_dir,"homfam/evaluation/tcs/*.tcs")
tcss_3d = os.path.join(evaluation_dir,"homfam/alignments/*/*/*.tcs")
tcs_paths = list(glob.glob(tcss)) + list(glob.glob(tcss_3d))
tcs_df_complete = pd.DataFrame()

# %%
for file in tcs_paths:
    full_name = file.split(sep = "/")[-1].replace(".tcs", "")
    file_opened = open(file, "r")
    #tot_line = [line.split(sep = ":") for line in file_opened if line.contains(':')]
    for line in file_opened: 
        if ":" in line and "CPU" not in line: 
            s_line = line.split(sep = ":")
            entry = pd.DataFrame({'name_3D':[full_name], 'sequence': [s_line[0].strip()],"tcs": s_line[1].strip()})
            tcs_df_complete =  pd.concat([tcs_df_complete, entry], ignore_index = True)

# %%
min_tcs = pd.DataFrame(tcs_df_complete.groupby(by = "name_3D")["tcs"].min()).reset_index()
min_tcs = min_tcs.rename(columns={'tcs': 'min_tcs'})
min_tcs = min_tcs.astype({'min_tcs':'int'})

# %%
df = pd.merge(df_d_r, min_tcs, on = "name_3D")
df["problematic_family"] = "ok"
df.loc[df.perc_change_sp < 0, 'problematic_family'] = "problematic"
df = df[df.family.isin(problematic_families.family)]

# %%
# 1. Expectations: TCS vs SP
plt.figure(figsize=(6,4.8))

x_var = "plddt_min_3D"
y_var = "sp_3D"
hue_var = "perc_change_sp"

sns.scatterplot(data = df, x = x_var, y = y_var, hue= hue_var, \
                edgecolor = "grey", linewidth = 0, palette = "rocket", s = 250)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = "% loss SP")

# %% [markdown]
# ## Are the same sequences having the low plddt the ones being the problem in TCS?

# %%
tcs_df_complete = tcs_df_complete.astype({'sequence':'str'})
tcs_df_complete = tcs_df_complete.astype({'tcs':'int'})

summary_ref_af2 = summary_ref_af2.astype({'sequence':'str'})

df = pd.merge(tcs_df_complete, summary_ref_af2, on = "sequence" )
df[["family", "method", "align_method", "tree_method"]] = df.name_3D.str.split(".", expand = True)

# %%
tcs_df_complete
# Out:
#                                  name_3D  sequence  tcs
# 0         aat-ref.progressive.FAMSA.MBED  1ajsa      74
# 1         aat-ref.progressive.FAMSA.MBED  1ama       75
# 2         aat-ref.progressive.FAMSA.MBED  1ars       75
# 3         aat-ref.progressive.FAMSA.MBED  1ay8a      74
# 4         aat-ref.progressive.FAMSA.MBED  1b8ga      52
# ...                                  ...       ...  ...
# 3491  p450-ref.progressive.3DCOFFEE.MBED     1jfba   93
# 3492  p450-ref.progressive.3DCOFFEE.MBED     1n40a   92
# 3493  p450-ref.progressive.3DCOFFEE.MBED      1cpt   92
# 3494  p450-ref.progressive.3DCOFFEE.MBED     1n97a   91
# 3495  p450-ref.progressive.3DCOFFEE.MBED      cons   92
#
# [3496 rows x 3 columns]

# %%
df = df[df.align_method == "3DCOFFEE"]

# %%
df
# Out:
#                                   name_3D sequence  tcs  length   name subset  \
# 1       aat-ref.progressive.3DCOFFEE.MBED    1ajsa   98     412    aat    ref
# 3       aat-ref.progressive.3DCOFFEE.MBED     1ama   98     401    aat    ref
# 5       aat-ref.progressive.3DCOFFEE.MBED     1ars   98     396    aat    ref
# 7       aat-ref.progressive.3DCOFFEE.MBED    1ay8a   98     394    aat    ref
# 9       aat-ref.progressive.3DCOFFEE.MBED    1b8ga   94     421    aat    ref
# ...                                   ...      ...  ...     ...    ...    ...
# 1537  ghf13-ref.progressive.3DCOFFEE.MBED     1cgt   95     502  ghf13    ref
# 1539  ghf13-ref.progressive.3DCOFFEE.MBED     1cyg   95     499  ghf13    ref
# 1541  ghf13-ref.progressive.3DCOFFEE.MBED     1jae   93     470  ghf13    ref
# 1543  ghf13-ref.progressive.3DCOFFEE.MBED     2aaa   94     476  ghf13    ref
# 1545  ghf13-ref.progressive.3DCOFFEE.MBED     6taa   94     476  ghf13    ref
#
#          family    plddt benchmarking_dataset       method align_method  \
# 1       aat-ref  89.1959               homfam  progressive     3DCOFFEE
# 3       aat-ref  89.0713               homfam  progressive     3DCOFFEE
# 5       aat-ref  88.1288               homfam  progressive     3DCOFFEE
# 7       aat-ref  88.2618               homfam  progressive     3DCOFFEE
# 9       aat-ref  88.0558               homfam  progressive     3DCOFFEE
# ...         ...      ...                  ...          ...          ...
# 1537  ghf13-ref  89.8259               homfam  progressive     3DCOFFEE
# 1539  ghf13-ref  89.1261               homfam  progressive     3DCOFFEE
# 1541  ghf13-ref  89.3641               homfam  progressive     3DCOFFEE
# 1543  ghf13-ref  89.6558               homfam  progressive     3DCOFFEE
# 1545  ghf13-ref  89.5266               homfam  progressive     3DCOFFEE
#
#      tree_method
# 1           MBED
# 3           MBED
# 5           MBED
# 7           MBED
# 9           MBED
# ...          ...
# 1537        MBED
# 1539        MBED
# 1541        MBED
# 1543        MBED
# 1545        MBED
#
# [773 rows x 12 columns]

# %%
# 1. Expectations: TCS vs SP
plt.figure(figsize=(6,4.8))

x_var = "plddt"
y_var = "tcs"
hue_var = "length"

sns.scatterplot(data = df, x = x_var, y = y_var, hue= hue_var, \
                edgecolor = "grey", linewidth = 0,  s = 30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = "length")

# %%
# Check only the problematic ones

# %%
problematic_families
# Out:
#                                           name_3D  sp_3D  tc_3D  column_3D  \
# 6               HLH-ref.progressive.3DCOFFEE.MBED   89.2   78.6       77.4
# 19          HMG_box-ref.progressive.3DCOFFEE.MBED   96.7   85.2       93.9
# 21              int-ref.progressive.3DCOFFEE.MBED   88.0   72.8       77.1
# 24              ins-ref.progressive.3DCOFFEE.MBED   87.8   56.5       77.9
# 25              rhv-ref.progressive.3DCOFFEE.MBED   57.0   33.3       41.7
# 27  myb_DNA-binding-ref.progressive.3DCOFFEE.MBED   89.8   69.6       78.2
# 30               hr-ref.progressive.3DCOFFEE.MBED   98.9   93.7       97.7
# 32            ChtBD-ref.progressive.3DCOFFEE.MBED   97.3   88.4       90.8
# 38              mmp-ref.progressive.3DCOFFEE.MBED   97.6   89.9       93.9
#
#              family    method_3D bucket_size_3D align_method_3D  \
# 6               HLH  progressive            NaN        3DCOFFEE
# 19          HMG_box  progressive            NaN        3DCOFFEE
# 21              int  progressive            NaN        3DCOFFEE
# 24              ins  progressive            NaN        3DCOFFEE
# 25              rhv  progressive            NaN        3DCOFFEE
# 27  myb_DNA-binding  progressive            NaN        3DCOFFEE
# 30               hr  progressive            NaN        3DCOFFEE
# 32            ChtBD  progressive            NaN        3DCOFFEE
# 38              mmp  progressive            NaN        3DCOFFEE
#
#    tree_method_3D dynamicX_label_3D  ... plddt_mean_FAMSA plddt_min_FAMSA  \
# 6            MBED               NaN  ...        73.734340         62.6524
# 19           MBED               NaN  ...        75.899900         68.6329
# 21           MBED               NaN  ...        84.861620         83.8319
# 24           MBED               NaN  ...        66.639933         59.9665
# 25           MBED               NaN  ...        71.582433         69.6655
# 27           MBED               NaN  ...        73.745080         69.1797
# 30           MBED               NaN  ...        79.470240         73.0645
# 32           MBED               NaN  ...        72.533880         70.6585
# 38           MBED               NaN  ...        85.521800         84.3517
#
#    plddt_max_FAMSA sim_tot_FAMSA tcs_tot_FAMSA  diff_tc  diff_sp  \
# 6          80.1354         27.98           795     -5.9     -2.4
# 19         80.1560         24.69           822      0.0     -0.6
# 21         86.2072         22.02           722     -2.4     -2.9
# 24         75.7398         44.79           936    -20.3     -8.5
# 25         73.3991         33.28           837    -17.1    -21.6
# 27         76.7059         40.86           848    -14.3     -7.0
# 30         82.8730         53.31           990     -6.3     -1.1
# 32         76.0055         58.72           941     -2.3     -1.0
# 38         85.9889         55.05           970     -3.0     -0.8
#
#     perc_change_tc  perc_change_sp diff_qualitatively
# 6        -6.982249       -2.620087             worst
# 19        0.000000       -0.616650             worst
# 21       -3.191489       -3.190319             worst
# 24      -26.432292       -8.826584             worst
# 25      -33.928571      -27.480916         worst -10
# 27      -17.044100       -7.231405             worst
# 30       -6.300000       -1.100000             worst
# 32       -2.535832       -1.017294             worst
# 38       -3.229279       -0.813008             worst
#
# [9 rows x 92 columns]

# %%
df_prob = df[df.name_3D.isin(problematic_families.name_3D)]

# %%
df_prob = pd.merge(df_prob, df_d_r, on = "name_3D")

# %%
print(list(df_prob.columns))
# Out:
# ['name_3D', 'sequence', 'tcs', 'length', 'name', 'subset', 'family_x', 'plddt', 'benchmarking_dataset', 'method', 'align_method', 'tree_method', 'sp_3D', 'tc_3D', 'column_3D', 'family_y', 'method_3D', 'bucket_size_3D', 'align_method_3D', 'tree_method_3D', 'dynamicX_label_3D', 'dynamicX_val_3D', 'master_msa_3D', 'slave_msa_3D', 'benchmarking_dataset_3D_3D', 'subset_3D', 'n_sequences_3D', 'mean_length_3D', 'min_length_3D', 'max_length_3D', 'file_3D', 'size_group_3D', 'perc_ref_total_3D_3D', 'approach_3D', 'fam_approach_3D', 'familcombined_3D', 'subset_ref_3D', 'n_sequences_ref_3D', 'mean_length_ref_3D', 'min_length_ref_3D', 'maref_length_ref_3D', 'file_ref_3D', 'subset_combined_3D', 'n_sequences_combined_3D', 'mean_length_combined_3D', 'min_length_combined_3D', 'maref_length_combined_3D', 'file_combined_3D', 'perc_ref_total_FAMSA_3D', 'benchmarking_dataset_FAMSA_3D', 'plddt_mean_3D', 'plddt_min_3D', 'plddt_max_3D', 'sim_tot_3D', 'tcs_tot_3D', 'name_FAMSA', 'sp_FAMSA', 'tc_FAMSA', 'column_FAMSA', 'method_FAMSA', 'bucket_size_FAMSA', 'align_method_FAMSA', 'tree_method_FAMSA', 'dynamicX_label_FAMSA', 'dynamicX_val_FAMSA', 'master_msa_FAMSA', 'slave_msa_FAMSA', 'benchmarking_dataset_3D_FAMSA', 'subset_FAMSA', 'n_sequences_FAMSA', 'mean_length_FAMSA', 'min_length_FAMSA', 'max_length_FAMSA', 'file_FAMSA', 'size_group_FAMSA', 'perc_ref_total_3D_FAMSA', 'approach_FAMSA', 'fam_approach_FAMSA', 'familcombined_FAMSA', 'subset_ref_FAMSA', 'n_sequences_ref_FAMSA', 'mean_length_ref_FAMSA', 'min_length_ref_FAMSA', 'maref_length_ref_FAMSA', 'file_ref_FAMSA', 'subset_combined_FAMSA', 'n_sequences_combined_FAMSA', 'mean_length_combined_FAMSA', 'min_length_combined_FAMSA', 'maref_length_combined_FAMSA', 'file_combined_FAMSA', 'perc_ref_total_FAMSA_FAMSA', 'benchmarking_dataset_FAMSA_FAMSA', 'plddt_mean_FAMSA', 'plddt_min_FAMSA', 'plddt_max_FAMSA', 'sim_tot_FAMSA', 'tcs_tot_FAMSA', 'diff_tc', 'diff_sp', 'perc_change_tc', 'perc_change_sp', 'diff_qualitatively']

# %%
# 1. Expectations: TCS vs SP
plt.figure(figsize=(6,4.8))

x_var = "plddt"
y_var = "sim_tot_3D"
hue_var = "perc_change_sp"

sns.scatterplot(data = df_prob, x = x_var, y = y_var, hue= hue_var, \
                edgecolor = "grey", linewidth = 0, palette = "rocket", s = 120)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = "% sp loss")

# %% [markdown]
# # Check really the super problematic family

# %%
df_prob[df_prob.perc_change_sp < -10][["tcs", "plddt", "sim_tot_3D","sim_tot_FAMSA"]]
# Out:
#     tcs    plddt  sim_tot_3D  sim_tot_FAMSA
# 31   95  70.0337       25.42          33.28
# 32   96  71.4577       25.42          33.28
# 33   95  71.7085       25.42          33.28
# 34   92  69.6655       25.42          33.28
# 35   96  73.3991       25.42          33.28
# 36   96  73.2301       25.42          33.28

# %%
df_prob
# Out:
#                                           name_3D sequence  tcs  length  \
# 0                hr-ref.progressive.3DCOFFEE.MBED     1hcp   99      75
# 1                hr-ref.progressive.3DCOFFEE.MBED     1hra   99      80
# 2                hr-ref.progressive.3DCOFFEE.MBED    1lata   99      71
# 3                hr-ref.progressive.3DCOFFEE.MBED    2nlla   99      66
# 4                hr-ref.progressive.3DCOFFEE.MBED    2nllb   98      78
# 5   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED    1a5j1   99      55
# 6   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED    1a5j2   99      55
# 7   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED     1ba5   98      53
# 8   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED   1msfc1   98      55
# 9   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED   1msfc2   99      50
# 10          HMG_box-ref.progressive.3DCOFFEE.MBED    1ckta   99      71
# 11          HMG_box-ref.progressive.3DCOFFEE.MBED     1hma   98      73
# 12          HMG_box-ref.progressive.3DCOFFEE.MBED    1hrza   99      73
# 13          HMG_box-ref.progressive.3DCOFFEE.MBED     1nhn   99      79
# 14          HMG_box-ref.progressive.3DCOFFEE.MBED    2lefa   99      86
# 15            ChtBD-ref.progressive.3DCOFFEE.MBED     1hev  100      43
# 16            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta1  100      42
# 17            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta2  100      43
# 18            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta3  100      43
# 19            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta4  100      42
# 20              mmp-ref.progressive.3DCOFFEE.MBED    1bqoa   99     169
# 21              mmp-ref.progressive.3DCOFFEE.MBED    1bqqm   99     174
# 22              mmp-ref.progressive.3DCOFFEE.MBED     1hfc   99     157
# 23              mmp-ref.progressive.3DCOFFEE.MBED    1mmpa   99     166
# 24              mmp-ref.progressive.3DCOFFEE.MBED     1mnc   99     158
# 25              mmp-ref.progressive.3DCOFFEE.MBED    456ca   99     160
# 26              int-ref.progressive.3DCOFFEE.MBED    1aoxa   98     201
# 27              int-ref.progressive.3DCOFFEE.MBED    1atza   98     184
# 28              int-ref.progressive.3DCOFFEE.MBED     1auq   97     208
# 29              int-ref.progressive.3DCOFFEE.MBED     1ido   98     184
# 30              int-ref.progressive.3DCOFFEE.MBED    1lfaa   98     183
# 31              rhv-ref.progressive.3DCOFFEE.MBED     1bbt   95     662
# 32              rhv-ref.progressive.3DCOFFEE.MBED     1r1a   96     793
# 33              rhv-ref.progressive.3DCOFFEE.MBED     1tme   95     766
# 34              rhv-ref.progressive.3DCOFFEE.MBED     2mev   92     806
# 35              rhv-ref.progressive.3DCOFFEE.MBED     2plv   96     854
# 36              rhv-ref.progressive.3DCOFFEE.MBED     4rhv   96     804
# 37              ins-ref.progressive.3DCOFFEE.MBED     1bom   97      47
# 38              ins-ref.progressive.3DCOFFEE.MBED     1igl   97      67
# 39              ins-ref.progressive.3DCOFFEE.MBED     2gf1   98      70
# 40              ins-ref.progressive.3DCOFFEE.MBED     2ins   96      50
# 41              ins-ref.progressive.3DCOFFEE.MBED     4ins   96      51
# 42              ins-ref.progressive.3DCOFFEE.MBED     6rlx   97      50
# 43              HLH-ref.progressive.3DCOFFEE.MBED    1a0aa   97      63
# 44              HLH-ref.progressive.3DCOFFEE.MBED    1am9a   98      80
# 45              HLH-ref.progressive.3DCOFFEE.MBED    1an4a   96      65
# 46              HLH-ref.progressive.3DCOFFEE.MBED    1hloa   97      80
# 47              HLH-ref.progressive.3DCOFFEE.MBED    1mdya   98      68
#
#                name subset             family_x    plddt benchmarking_dataset  \
# 0                hr    ref               hr-ref  79.7318               homfam
# 1                hr    ref               hr-ref  73.0645               homfam
# 2                hr    ref               hr-ref  80.7891               homfam
# 3                hr    ref               hr-ref  80.8928               homfam
# 4                hr    ref               hr-ref  82.8730               homfam
# 5   myb_DNA-binding    ref  myb_DNA-binding-ref  76.4785               homfam
# 6   myb_DNA-binding    ref  myb_DNA-binding-ref  72.6571               homfam
# 7   myb_DNA-binding    ref  myb_DNA-binding-ref  76.7059               homfam
# 8   myb_DNA-binding    ref  myb_DNA-binding-ref  69.1797               homfam
# 9   myb_DNA-binding    ref  myb_DNA-binding-ref  73.7042               homfam
# 10          HMG_box    ref          HMG_box-ref  78.7071               homfam
# 11          HMG_box    ref          HMG_box-ref  80.1560               homfam
# 12          HMG_box    ref          HMG_box-ref  80.0608               homfam
# 13          HMG_box    ref          HMG_box-ref  71.9427               homfam
# 14          HMG_box    ref          HMG_box-ref  68.6329               homfam
# 15            ChtBD    ref            ChtBD-ref  76.0055               homfam
# 16            ChtBD    ref            ChtBD-ref  73.0063               homfam
# 17            ChtBD    ref            ChtBD-ref  71.4080               homfam
# 18            ChtBD    ref            ChtBD-ref  71.5911               homfam
# 19            ChtBD    ref            ChtBD-ref  70.6585               homfam
# 20              mmp    ref              mmp-ref  85.9079               homfam
# 21              mmp    ref              mmp-ref  84.3517               homfam
# 22              mmp    ref              mmp-ref  85.9139               homfam
# 23              mmp    ref              mmp-ref  85.8776               homfam
# 24              mmp    ref              mmp-ref  85.9889               homfam
# 25              mmp    ref              mmp-ref  85.0908               homfam
# 26              int    ref              int-ref  85.6173               homfam
# 27              int    ref              int-ref  84.4267               homfam
# 28              int    ref              int-ref  86.2072               homfam
# 29              int    ref              int-ref  83.8319               homfam
# 30              int    ref              int-ref  84.2250               homfam
# 31              rhv    ref              rhv-ref  70.0337               homfam
# 32              rhv    ref              rhv-ref  71.4577               homfam
# 33              rhv    ref              rhv-ref  71.7085               homfam
# 34              rhv    ref              rhv-ref  69.6655               homfam
# 35              rhv    ref              rhv-ref  73.3991               homfam
# 36              rhv    ref              rhv-ref  73.2301               homfam
# 37              ins    ref              ins-ref  61.8673               homfam
# 38              ins    ref              ins-ref  59.9665               homfam
# 39              ins    ref              ins-ref  62.8152               homfam
# 40              ins    ref              ins-ref  70.2806               homfam
# 41              ins    ref              ins-ref  69.1702               homfam
# 42              ins    ref              ins-ref  75.7398               homfam
# 43              HLH    ref              HLH-ref  69.3571               homfam
# 44              HLH    ref              HLH-ref  80.1354               homfam
# 45              HLH    ref              HLH-ref  62.6524               homfam
# 46              HLH    ref              HLH-ref  78.8959               homfam
# 47              HLH    ref              HLH-ref  77.6309               homfam
#
#          method  ... plddt_mean_FAMSA plddt_min_FAMSA  plddt_max_FAMSA  \
# 0   progressive  ...        79.470240         73.0645          82.8730
# 1   progressive  ...        79.470240         73.0645          82.8730
# 2   progressive  ...        79.470240         73.0645          82.8730
# 3   progressive  ...        79.470240         73.0645          82.8730
# 4   progressive  ...        79.470240         73.0645          82.8730
# 5   progressive  ...        73.745080         69.1797          76.7059
# 6   progressive  ...        73.745080         69.1797          76.7059
# 7   progressive  ...        73.745080         69.1797          76.7059
# 8   progressive  ...        73.745080         69.1797          76.7059
# 9   progressive  ...        73.745080         69.1797          76.7059
# 10  progressive  ...        75.899900         68.6329          80.1560
# 11  progressive  ...        75.899900         68.6329          80.1560
# 12  progressive  ...        75.899900         68.6329          80.1560
# 13  progressive  ...        75.899900         68.6329          80.1560
# 14  progressive  ...        75.899900         68.6329          80.1560
# 15  progressive  ...        72.533880         70.6585          76.0055
# 16  progressive  ...        72.533880         70.6585          76.0055
# 17  progressive  ...        72.533880         70.6585          76.0055
# 18  progressive  ...        72.533880         70.6585          76.0055
# 19  progressive  ...        72.533880         70.6585          76.0055
# 20  progressive  ...        85.521800         84.3517          85.9889
# 21  progressive  ...        85.521800         84.3517          85.9889
# 22  progressive  ...        85.521800         84.3517          85.9889
# 23  progressive  ...        85.521800         84.3517          85.9889
# 24  progressive  ...        85.521800         84.3517          85.9889
# 25  progressive  ...        85.521800         84.3517          85.9889
# 26  progressive  ...        84.861620         83.8319          86.2072
# 27  progressive  ...        84.861620         83.8319          86.2072
# 28  progressive  ...        84.861620         83.8319          86.2072
# 29  progressive  ...        84.861620         83.8319          86.2072
# 30  progressive  ...        84.861620         83.8319          86.2072
# 31  progressive  ...        71.582433         69.6655          73.3991
# 32  progressive  ...        71.582433         69.6655          73.3991
# 33  progressive  ...        71.582433         69.6655          73.3991
# 34  progressive  ...        71.582433         69.6655          73.3991
# 35  progressive  ...        71.582433         69.6655          73.3991
# 36  progressive  ...        71.582433         69.6655          73.3991
# 37  progressive  ...        66.639933         59.9665          75.7398
# 38  progressive  ...        66.639933         59.9665          75.7398
# 39  progressive  ...        66.639933         59.9665          75.7398
# 40  progressive  ...        66.639933         59.9665          75.7398
# 41  progressive  ...        66.639933         59.9665          75.7398
# 42  progressive  ...        66.639933         59.9665          75.7398
# 43  progressive  ...        73.734340         62.6524          80.1354
# 44  progressive  ...        73.734340         62.6524          80.1354
# 45  progressive  ...        73.734340         62.6524          80.1354
# 46  progressive  ...        73.734340         62.6524          80.1354
# 47  progressive  ...        73.734340         62.6524          80.1354
#
#     sim_tot_FAMSA  tcs_tot_FAMSA diff_tc diff_sp perc_change_tc  \
# 0           53.31            990    -6.3    -1.1      -6.300000
# 1           53.31            990    -6.3    -1.1      -6.300000
# 2           53.31            990    -6.3    -1.1      -6.300000
# 3           53.31            990    -6.3    -1.1      -6.300000
# 4           53.31            990    -6.3    -1.1      -6.300000
# 5           40.86            848   -14.3    -7.0     -17.044100
# 6           40.86            848   -14.3    -7.0     -17.044100
# 7           40.86            848   -14.3    -7.0     -17.044100
# 8           40.86            848   -14.3    -7.0     -17.044100
# 9           40.86            848   -14.3    -7.0     -17.044100
# 10          24.69            822     0.0    -0.6       0.000000
# 11          24.69            822     0.0    -0.6       0.000000
# 12          24.69            822     0.0    -0.6       0.000000
# 13          24.69            822     0.0    -0.6       0.000000
# 14          24.69            822     0.0    -0.6       0.000000
# 15          58.72            941    -2.3    -1.0      -2.535832
# 16          58.72            941    -2.3    -1.0      -2.535832
# 17          58.72            941    -2.3    -1.0      -2.535832
# 18          58.72            941    -2.3    -1.0      -2.535832
# 19          58.72            941    -2.3    -1.0      -2.535832
# 20          55.05            970    -3.0    -0.8      -3.229279
# 21          55.05            970    -3.0    -0.8      -3.229279
# 22          55.05            970    -3.0    -0.8      -3.229279
# 23          55.05            970    -3.0    -0.8      -3.229279
# 24          55.05            970    -3.0    -0.8      -3.229279
# 25          55.05            970    -3.0    -0.8      -3.229279
# 26          22.02            722    -2.4    -2.9      -3.191489
# 27          22.02            722    -2.4    -2.9      -3.191489
# 28          22.02            722    -2.4    -2.9      -3.191489
# 29          22.02            722    -2.4    -2.9      -3.191489
# 30          22.02            722    -2.4    -2.9      -3.191489
# 31          33.28            837   -17.1   -21.6     -33.928571
# 32          33.28            837   -17.1   -21.6     -33.928571
# 33          33.28            837   -17.1   -21.6     -33.928571
# 34          33.28            837   -17.1   -21.6     -33.928571
# 35          33.28            837   -17.1   -21.6     -33.928571
# 36          33.28            837   -17.1   -21.6     -33.928571
# 37          44.79            936   -20.3    -8.5     -26.432292
# 38          44.79            936   -20.3    -8.5     -26.432292
# 39          44.79            936   -20.3    -8.5     -26.432292
# 40          44.79            936   -20.3    -8.5     -26.432292
# 41          44.79            936   -20.3    -8.5     -26.432292
# 42          44.79            936   -20.3    -8.5     -26.432292
# 43          27.98            795    -5.9    -2.4      -6.982249
# 44          27.98            795    -5.9    -2.4      -6.982249
# 45          27.98            795    -5.9    -2.4      -6.982249
# 46          27.98            795    -5.9    -2.4      -6.982249
# 47          27.98            795    -5.9    -2.4      -6.982249
#
#    perc_change_sp diff_qualitatively
# 0       -1.100000             worst
# 1       -1.100000             worst
# 2       -1.100000             worst
# 3       -1.100000             worst
# 4       -1.100000             worst
# 5       -7.231405             worst
# 6       -7.231405             worst
# 7       -7.231405             worst
# 8       -7.231405             worst
# 9       -7.231405             worst
# 10      -0.616650             worst
# 11      -0.616650             worst
# 12      -0.616650             worst
# 13      -0.616650             worst
# 14      -0.616650             worst
# 15      -1.017294             worst
# 16      -1.017294             worst
# 17      -1.017294             worst
# 18      -1.017294             worst
# 19      -1.017294             worst
# 20      -0.813008             worst
# 21      -0.813008             worst
# 22      -0.813008             worst
# 23      -0.813008             worst
# 24      -0.813008             worst
# 25      -0.813008             worst
# 26      -3.190319             worst
# 27      -3.190319             worst
# 28      -3.190319             worst
# 29      -3.190319             worst
# 30      -3.190319             worst
# 31     -27.480916         worst -10
# 32     -27.480916         worst -10
# 33     -27.480916         worst -10
# 34     -27.480916         worst -10
# 35     -27.480916         worst -10
# 36     -27.480916         worst -10
# 37      -8.826584             worst
# 38      -8.826584             worst
# 39      -8.826584             worst
# 40      -8.826584             worst
# 41      -8.826584             worst
# 42      -8.826584             worst
# 43      -2.620087             worst
# 44      -2.620087             worst
# 45      -2.620087             worst
# 46      -2.620087             worst
# 47      -2.620087             worst
#
# [48 rows x 103 columns]

# %%
list(df_prob.columns)
# Out:
# ['name_3D',
#  'sequence',
#  'tcs',
#  'length',
#  'name',
#  'subset',
#  'family_x',
#  'plddt',
#  'benchmarking_dataset',
#  'method',
#  'align_method',
#  'tree_method',
#  'sp_3D',
#  'tc_3D',
#  'column_3D',
#  'family_y',
#  'method_3D',
#  'bucket_size_3D',
#  'align_method_3D',
#  'tree_method_3D',
#  'dynamicX_label_3D',
#  'dynamicX_val_3D',
#  'master_msa_3D',
#  'slave_msa_3D',
#  'benchmarking_dataset_3D_3D',
#  'subset_3D',
#  'n_sequences_3D',
#  'mean_length_3D',
#  'min_length_3D',
#  'max_length_3D',
#  'file_3D',
#  'size_group_3D',
#  'perc_ref_total_3D_3D',
#  'approach_3D',
#  'fam_approach_3D',
#  'familcombined_3D',
#  'subset_ref_3D',
#  'n_sequences_ref_3D',
#  'mean_length_ref_3D',
#  'min_length_ref_3D',
#  'maref_length_ref_3D',
#  'file_ref_3D',
#  'subset_combined_3D',
#  'n_sequences_combined_3D',
#  'mean_length_combined_3D',
#  'min_length_combined_3D',
#  'maref_length_combined_3D',
#  'file_combined_3D',
#  'perc_ref_total_FAMSA_3D',
#  'benchmarking_dataset_FAMSA_3D',
#  'plddt_mean_3D',
#  'plddt_min_3D',
#  'plddt_max_3D',
#  'sim_tot_3D',
#  'tcs_tot_3D',
#  'name_FAMSA',
#  'sp_FAMSA',
#  'tc_FAMSA',
#  'column_FAMSA',
#  'method_FAMSA',
#  'bucket_size_FAMSA',
#  'align_method_FAMSA',
#  'tree_method_FAMSA',
#  'dynamicX_label_FAMSA',
#  'dynamicX_val_FAMSA',
#  'master_msa_FAMSA',
#  'slave_msa_FAMSA',
#  'benchmarking_dataset_3D_FAMSA',
#  'subset_FAMSA',
#  'n_sequences_FAMSA',
#  'mean_length_FAMSA',
#  'min_length_FAMSA',
#  'max_length_FAMSA',
#  'file_FAMSA',
#  'size_group_FAMSA',
#  'perc_ref_total_3D_FAMSA',
#  'approach_FAMSA',
#  'fam_approach_FAMSA',
#  'familcombined_FAMSA',
#  'subset_ref_FAMSA',
#  'n_sequences_ref_FAMSA',
#  'mean_length_ref_FAMSA',
#  'min_length_ref_FAMSA',
#  'maref_length_ref_FAMSA',
#  'file_ref_FAMSA',
#  'subset_combined_FAMSA',
#  'n_sequences_combined_FAMSA',
#  'mean_length_combined_FAMSA',
#  'min_length_combined_FAMSA',
#  'maref_length_combined_FAMSA',
#  'file_combined_FAMSA',
#  'perc_ref_total_FAMSA_FAMSA',
#  'benchmarking_dataset_FAMSA_FAMSA',
#  'plddt_mean_FAMSA',
#  'plddt_min_FAMSA',
#  'plddt_max_FAMSA',
#  'sim_tot_FAMSA',
#  'tcs_tot_FAMSA',
#  'diff_tc',
#  'diff_sp',
#  'perc_change_tc',
#  'perc_change_sp',
#  'diff_qualitatively']

# %%
df_prob = df_prob.rename(columns={"name_3D": "name_full"})
easel = easel.rename(columns={"name": "name_full"})

# %%
df_prob
# Out:
#                                              name sequence  tcs  length  \
# 0                hr-ref.progressive.3DCOFFEE.MBED     1hcp   99      75
# 1                hr-ref.progressive.3DCOFFEE.MBED     1hra   99      80
# 2                hr-ref.progressive.3DCOFFEE.MBED    1lata   99      71
# 3                hr-ref.progressive.3DCOFFEE.MBED    2nlla   99      66
# 4                hr-ref.progressive.3DCOFFEE.MBED    2nllb   98      78
# 5   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED    1a5j1   99      55
# 6   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED    1a5j2   99      55
# 7   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED     1ba5   98      53
# 8   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED   1msfc1   98      55
# 9   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED   1msfc2   99      50
# 10          HMG_box-ref.progressive.3DCOFFEE.MBED    1ckta   99      71
# 11          HMG_box-ref.progressive.3DCOFFEE.MBED     1hma   98      73
# 12          HMG_box-ref.progressive.3DCOFFEE.MBED    1hrza   99      73
# 13          HMG_box-ref.progressive.3DCOFFEE.MBED     1nhn   99      79
# 14          HMG_box-ref.progressive.3DCOFFEE.MBED    2lefa   99      86
# 15            ChtBD-ref.progressive.3DCOFFEE.MBED     1hev  100      43
# 16            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta1  100      42
# 17            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta2  100      43
# 18            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta3  100      43
# 19            ChtBD-ref.progressive.3DCOFFEE.MBED   1wgta4  100      42
# 20              mmp-ref.progressive.3DCOFFEE.MBED    1bqoa   99     169
# 21              mmp-ref.progressive.3DCOFFEE.MBED    1bqqm   99     174
# 22              mmp-ref.progressive.3DCOFFEE.MBED     1hfc   99     157
# 23              mmp-ref.progressive.3DCOFFEE.MBED    1mmpa   99     166
# 24              mmp-ref.progressive.3DCOFFEE.MBED     1mnc   99     158
# 25              mmp-ref.progressive.3DCOFFEE.MBED    456ca   99     160
# 26              int-ref.progressive.3DCOFFEE.MBED    1aoxa   98     201
# 27              int-ref.progressive.3DCOFFEE.MBED    1atza   98     184
# 28              int-ref.progressive.3DCOFFEE.MBED     1auq   97     208
# 29              int-ref.progressive.3DCOFFEE.MBED     1ido   98     184
# 30              int-ref.progressive.3DCOFFEE.MBED    1lfaa   98     183
# 31              rhv-ref.progressive.3DCOFFEE.MBED     1bbt   95     662
# 32              rhv-ref.progressive.3DCOFFEE.MBED     1r1a   96     793
# 33              rhv-ref.progressive.3DCOFFEE.MBED     1tme   95     766
# 34              rhv-ref.progressive.3DCOFFEE.MBED     2mev   92     806
# 35              rhv-ref.progressive.3DCOFFEE.MBED     2plv   96     854
# 36              rhv-ref.progressive.3DCOFFEE.MBED     4rhv   96     804
# 37              ins-ref.progressive.3DCOFFEE.MBED     1bom   97      47
# 38              ins-ref.progressive.3DCOFFEE.MBED     1igl   97      67
# 39              ins-ref.progressive.3DCOFFEE.MBED     2gf1   98      70
# 40              ins-ref.progressive.3DCOFFEE.MBED     2ins   96      50
# 41              ins-ref.progressive.3DCOFFEE.MBED     4ins   96      51
# 42              ins-ref.progressive.3DCOFFEE.MBED     6rlx   97      50
# 43              HLH-ref.progressive.3DCOFFEE.MBED    1a0aa   97      63
# 44              HLH-ref.progressive.3DCOFFEE.MBED    1am9a   98      80
# 45              HLH-ref.progressive.3DCOFFEE.MBED    1an4a   96      65
# 46              HLH-ref.progressive.3DCOFFEE.MBED    1hloa   97      80
# 47              HLH-ref.progressive.3DCOFFEE.MBED    1mdya   98      68
#
#                name subset             family_x    plddt benchmarking_dataset  \
# 0                hr    ref               hr-ref  79.7318               homfam
# 1                hr    ref               hr-ref  73.0645               homfam
# 2                hr    ref               hr-ref  80.7891               homfam
# 3                hr    ref               hr-ref  80.8928               homfam
# 4                hr    ref               hr-ref  82.8730               homfam
# 5   myb_DNA-binding    ref  myb_DNA-binding-ref  76.4785               homfam
# 6   myb_DNA-binding    ref  myb_DNA-binding-ref  72.6571               homfam
# 7   myb_DNA-binding    ref  myb_DNA-binding-ref  76.7059               homfam
# 8   myb_DNA-binding    ref  myb_DNA-binding-ref  69.1797               homfam
# 9   myb_DNA-binding    ref  myb_DNA-binding-ref  73.7042               homfam
# 10          HMG_box    ref          HMG_box-ref  78.7071               homfam
# 11          HMG_box    ref          HMG_box-ref  80.1560               homfam
# 12          HMG_box    ref          HMG_box-ref  80.0608               homfam
# 13          HMG_box    ref          HMG_box-ref  71.9427               homfam
# 14          HMG_box    ref          HMG_box-ref  68.6329               homfam
# 15            ChtBD    ref            ChtBD-ref  76.0055               homfam
# 16            ChtBD    ref            ChtBD-ref  73.0063               homfam
# 17            ChtBD    ref            ChtBD-ref  71.4080               homfam
# 18            ChtBD    ref            ChtBD-ref  71.5911               homfam
# 19            ChtBD    ref            ChtBD-ref  70.6585               homfam
# 20              mmp    ref              mmp-ref  85.9079               homfam
# 21              mmp    ref              mmp-ref  84.3517               homfam
# 22              mmp    ref              mmp-ref  85.9139               homfam
# 23              mmp    ref              mmp-ref  85.8776               homfam
# 24              mmp    ref              mmp-ref  85.9889               homfam
# 25              mmp    ref              mmp-ref  85.0908               homfam
# 26              int    ref              int-ref  85.6173               homfam
# 27              int    ref              int-ref  84.4267               homfam
# 28              int    ref              int-ref  86.2072               homfam
# 29              int    ref              int-ref  83.8319               homfam
# 30              int    ref              int-ref  84.2250               homfam
# 31              rhv    ref              rhv-ref  70.0337               homfam
# 32              rhv    ref              rhv-ref  71.4577               homfam
# 33              rhv    ref              rhv-ref  71.7085               homfam
# 34              rhv    ref              rhv-ref  69.6655               homfam
# 35              rhv    ref              rhv-ref  73.3991               homfam
# 36              rhv    ref              rhv-ref  73.2301               homfam
# 37              ins    ref              ins-ref  61.8673               homfam
# 38              ins    ref              ins-ref  59.9665               homfam
# 39              ins    ref              ins-ref  62.8152               homfam
# 40              ins    ref              ins-ref  70.2806               homfam
# 41              ins    ref              ins-ref  69.1702               homfam
# 42              ins    ref              ins-ref  75.7398               homfam
# 43              HLH    ref              HLH-ref  69.3571               homfam
# 44              HLH    ref              HLH-ref  80.1354               homfam
# 45              HLH    ref              HLH-ref  62.6524               homfam
# 46              HLH    ref              HLH-ref  78.8959               homfam
# 47              HLH    ref              HLH-ref  77.6309               homfam
#
#          method  ... plddt_mean_FAMSA plddt_min_FAMSA  plddt_max_FAMSA  \
# 0   progressive  ...        79.470240         73.0645          82.8730
# 1   progressive  ...        79.470240         73.0645          82.8730
# 2   progressive  ...        79.470240         73.0645          82.8730
# 3   progressive  ...        79.470240         73.0645          82.8730
# 4   progressive  ...        79.470240         73.0645          82.8730
# 5   progressive  ...        73.745080         69.1797          76.7059
# 6   progressive  ...        73.745080         69.1797          76.7059
# 7   progressive  ...        73.745080         69.1797          76.7059
# 8   progressive  ...        73.745080         69.1797          76.7059
# 9   progressive  ...        73.745080         69.1797          76.7059
# 10  progressive  ...        75.899900         68.6329          80.1560
# 11  progressive  ...        75.899900         68.6329          80.1560
# 12  progressive  ...        75.899900         68.6329          80.1560
# 13  progressive  ...        75.899900         68.6329          80.1560
# 14  progressive  ...        75.899900         68.6329          80.1560
# 15  progressive  ...        72.533880         70.6585          76.0055
# 16  progressive  ...        72.533880         70.6585          76.0055
# 17  progressive  ...        72.533880         70.6585          76.0055
# 18  progressive  ...        72.533880         70.6585          76.0055
# 19  progressive  ...        72.533880         70.6585          76.0055
# 20  progressive  ...        85.521800         84.3517          85.9889
# 21  progressive  ...        85.521800         84.3517          85.9889
# 22  progressive  ...        85.521800         84.3517          85.9889
# 23  progressive  ...        85.521800         84.3517          85.9889
# 24  progressive  ...        85.521800         84.3517          85.9889
# 25  progressive  ...        85.521800         84.3517          85.9889
# 26  progressive  ...        84.861620         83.8319          86.2072
# 27  progressive  ...        84.861620         83.8319          86.2072
# 28  progressive  ...        84.861620         83.8319          86.2072
# 29  progressive  ...        84.861620         83.8319          86.2072
# 30  progressive  ...        84.861620         83.8319          86.2072
# 31  progressive  ...        71.582433         69.6655          73.3991
# 32  progressive  ...        71.582433         69.6655          73.3991
# 33  progressive  ...        71.582433         69.6655          73.3991
# 34  progressive  ...        71.582433         69.6655          73.3991
# 35  progressive  ...        71.582433         69.6655          73.3991
# 36  progressive  ...        71.582433         69.6655          73.3991
# 37  progressive  ...        66.639933         59.9665          75.7398
# 38  progressive  ...        66.639933         59.9665          75.7398
# 39  progressive  ...        66.639933         59.9665          75.7398
# 40  progressive  ...        66.639933         59.9665          75.7398
# 41  progressive  ...        66.639933         59.9665          75.7398
# 42  progressive  ...        66.639933         59.9665          75.7398
# 43  progressive  ...        73.734340         62.6524          80.1354
# 44  progressive  ...        73.734340         62.6524          80.1354
# 45  progressive  ...        73.734340         62.6524          80.1354
# 46  progressive  ...        73.734340         62.6524          80.1354
# 47  progressive  ...        73.734340         62.6524          80.1354
#
#     sim_tot_FAMSA  tcs_tot_FAMSA diff_tc diff_sp perc_change_tc  \
# 0           53.31            990    -6.3    -1.1      -6.300000
# 1           53.31            990    -6.3    -1.1      -6.300000
# 2           53.31            990    -6.3    -1.1      -6.300000
# 3           53.31            990    -6.3    -1.1      -6.300000
# 4           53.31            990    -6.3    -1.1      -6.300000
# 5           40.86            848   -14.3    -7.0     -17.044100
# 6           40.86            848   -14.3    -7.0     -17.044100
# 7           40.86            848   -14.3    -7.0     -17.044100
# 8           40.86            848   -14.3    -7.0     -17.044100
# 9           40.86            848   -14.3    -7.0     -17.044100
# 10          24.69            822     0.0    -0.6       0.000000
# 11          24.69            822     0.0    -0.6       0.000000
# 12          24.69            822     0.0    -0.6       0.000000
# 13          24.69            822     0.0    -0.6       0.000000
# 14          24.69            822     0.0    -0.6       0.000000
# 15          58.72            941    -2.3    -1.0      -2.535832
# 16          58.72            941    -2.3    -1.0      -2.535832
# 17          58.72            941    -2.3    -1.0      -2.535832
# 18          58.72            941    -2.3    -1.0      -2.535832
# 19          58.72            941    -2.3    -1.0      -2.535832
# 20          55.05            970    -3.0    -0.8      -3.229279
# 21          55.05            970    -3.0    -0.8      -3.229279
# 22          55.05            970    -3.0    -0.8      -3.229279
# 23          55.05            970    -3.0    -0.8      -3.229279
# 24          55.05            970    -3.0    -0.8      -3.229279
# 25          55.05            970    -3.0    -0.8      -3.229279
# 26          22.02            722    -2.4    -2.9      -3.191489
# 27          22.02            722    -2.4    -2.9      -3.191489
# 28          22.02            722    -2.4    -2.9      -3.191489
# 29          22.02            722    -2.4    -2.9      -3.191489
# 30          22.02            722    -2.4    -2.9      -3.191489
# 31          33.28            837   -17.1   -21.6     -33.928571
# 32          33.28            837   -17.1   -21.6     -33.928571
# 33          33.28            837   -17.1   -21.6     -33.928571
# 34          33.28            837   -17.1   -21.6     -33.928571
# 35          33.28            837   -17.1   -21.6     -33.928571
# 36          33.28            837   -17.1   -21.6     -33.928571
# 37          44.79            936   -20.3    -8.5     -26.432292
# 38          44.79            936   -20.3    -8.5     -26.432292
# 39          44.79            936   -20.3    -8.5     -26.432292
# 40          44.79            936   -20.3    -8.5     -26.432292
# 41          44.79            936   -20.3    -8.5     -26.432292
# 42          44.79            936   -20.3    -8.5     -26.432292
# 43          27.98            795    -5.9    -2.4      -6.982249
# 44          27.98            795    -5.9    -2.4      -6.982249
# 45          27.98            795    -5.9    -2.4      -6.982249
# 46          27.98            795    -5.9    -2.4      -6.982249
# 47          27.98            795    -5.9    -2.4      -6.982249
#
#    perc_change_sp diff_qualitatively
# 0       -1.100000             worst
# 1       -1.100000             worst
# 2       -1.100000             worst
# 3       -1.100000             worst
# 4       -1.100000             worst
# 5       -7.231405             worst
# 6       -7.231405             worst
# 7       -7.231405             worst
# 8       -7.231405             worst
# 9       -7.231405             worst
# 10      -0.616650             worst
# 11      -0.616650             worst
# 12      -0.616650             worst
# 13      -0.616650             worst
# 14      -0.616650             worst
# 15      -1.017294             worst
# 16      -1.017294             worst
# 17      -1.017294             worst
# 18      -1.017294             worst
# 19      -1.017294             worst
# 20      -0.813008             worst
# 21      -0.813008             worst
# 22      -0.813008             worst
# 23      -0.813008             worst
# 24      -0.813008             worst
# 25      -0.813008             worst
# 26      -3.190319             worst
# 27      -3.190319             worst
# 28      -3.190319             worst
# 29      -3.190319             worst
# 30      -3.190319             worst
# 31     -27.480916         worst -10
# 32     -27.480916         worst -10
# 33     -27.480916         worst -10
# 34     -27.480916         worst -10
# 35     -27.480916         worst -10
# 36     -27.480916         worst -10
# 37      -8.826584             worst
# 38      -8.826584             worst
# 39      -8.826584             worst
# 40      -8.826584             worst
# 41      -8.826584             worst
# 42      -8.826584             worst
# 43      -2.620087             worst
# 44      -2.620087             worst
# 45      -2.620087             worst
# 46      -2.620087             worst
# 47      -2.620087             worst
#
# [48 rows x 103 columns]

# %%
df_correlation_all[["name_full", "Average identity", "sim_tot_FAMSA"]]
# Out:
#                                         name_full Average identity  \
# 0   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED              38%
# 1   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED              38%
# 2   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED              38%
# 3   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED              38%
# 4   myb_DNA-binding-ref.progressive.3DCOFFEE.MBED              38%
# 5               int-ref.progressive.3DCOFFEE.MBED              21%
# 6               int-ref.progressive.3DCOFFEE.MBED              21%
# 7               int-ref.progressive.3DCOFFEE.MBED              21%
# 8               int-ref.progressive.3DCOFFEE.MBED              21%
# 9               int-ref.progressive.3DCOFFEE.MBED              21%
# 10              ins-ref.progressive.3DCOFFEE.MBED              41%
# 11              ins-ref.progressive.3DCOFFEE.MBED              41%
# 12              ins-ref.progressive.3DCOFFEE.MBED              41%
# 13              ins-ref.progressive.3DCOFFEE.MBED              41%
# 14              ins-ref.progressive.3DCOFFEE.MBED              41%
# 15              ins-ref.progressive.3DCOFFEE.MBED              41%
# 16               hr-ref.progressive.3DCOFFEE.MBED              53%
# 17               hr-ref.progressive.3DCOFFEE.MBED              53%
# 18               hr-ref.progressive.3DCOFFEE.MBED              53%
# 19               hr-ref.progressive.3DCOFFEE.MBED              53%
# 20               hr-ref.progressive.3DCOFFEE.MBED              53%
# 21              HLH-ref.progressive.3DCOFFEE.MBED              26%
# 22              HLH-ref.progressive.3DCOFFEE.MBED              26%
# 23              HLH-ref.progressive.3DCOFFEE.MBED              26%
# 24              HLH-ref.progressive.3DCOFFEE.MBED              26%
# 25              HLH-ref.progressive.3DCOFFEE.MBED              26%
# 26            ChtBD-ref.progressive.3DCOFFEE.MBED              58%
# 27            ChtBD-ref.progressive.3DCOFFEE.MBED              58%
# 28            ChtBD-ref.progressive.3DCOFFEE.MBED              58%
# 29            ChtBD-ref.progressive.3DCOFFEE.MBED              58%
# 30            ChtBD-ref.progressive.3DCOFFEE.MBED              58%
# 31              rhv-ref.progressive.3DCOFFEE.MBED              23%
# 32              rhv-ref.progressive.3DCOFFEE.MBED              23%
# 33              rhv-ref.progressive.3DCOFFEE.MBED              23%
# 34              rhv-ref.progressive.3DCOFFEE.MBED              23%
# 35              rhv-ref.progressive.3DCOFFEE.MBED              23%
# 36              rhv-ref.progressive.3DCOFFEE.MBED              23%
# 37          HMG_box-ref.progressive.3DCOFFEE.MBED              23%
# 38          HMG_box-ref.progressive.3DCOFFEE.MBED              23%
# 39          HMG_box-ref.progressive.3DCOFFEE.MBED              23%
# 40          HMG_box-ref.progressive.3DCOFFEE.MBED              23%
# 41          HMG_box-ref.progressive.3DCOFFEE.MBED              23%
# 42              mmp-ref.progressive.3DCOFFEE.MBED              54%
# 43              mmp-ref.progressive.3DCOFFEE.MBED              54%
# 44              mmp-ref.progressive.3DCOFFEE.MBED              54%
# 45              mmp-ref.progressive.3DCOFFEE.MBED              54%
# 46              mmp-ref.progressive.3DCOFFEE.MBED              54%
# 47              mmp-ref.progressive.3DCOFFEE.MBED              54%
#
#     sim_tot_FAMSA
# 0           40.86
# 1           40.86
# 2           40.86
# 3           40.86
# 4           40.86
# 5           22.02
# 6           22.02
# 7           22.02
# 8           22.02
# 9           22.02
# 10          44.79
# 11          44.79
# 12          44.79
# 13          44.79
# 14          44.79
# 15          44.79
# 16          53.31
# 17          53.31
# 18          53.31
# 19          53.31
# 20          53.31
# 21          27.98
# 22          27.98
# 23          27.98
# 24          27.98
# 25          27.98
# 26          58.72
# 27          58.72
# 28          58.72
# 29          58.72
# 30          58.72
# 31          33.28
# 32          33.28
# 33          33.28
# 34          33.28
# 35          33.28
# 36          33.28
# 37          24.69
# 38          24.69
# 39          24.69
# 40          24.69
# 41          24.69
# 42          55.05
# 43          55.05
# 44          55.05
# 45          55.05
# 46          55.05
# 47          55.05

# %%
df_correlation_all = pd.merge(easel, df_prob, on = "name_full")
df_correlation = df_correlation_all[["diff_tc","tc_3D","tc_FAMSA",\
                          "sp_3D","sp_FAMSA", "mean_length_3D",\
                          "plddt_min_3D", "plddt_mean_3D", "sim_tot_3D",\
                          "tcs_tot_3D", "sim_tot_FAMSA", "tcs_tot_FAMSA",\
                          "perc_change_sp", "Alignment length", "Average identity", "Average length"]]

#df_correlation.columns = ["diff_tc", "tc_structure", "tc_nostructure", "n_sequences_family", "mean_length", "plddt_mean"]
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests
def get_correlations(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how="outer")
    correlations = dfcols.transpose().join(dfcols, how="outer")
    for ix, r in enumerate(df.columns):
        for jx, c in enumerate(df.columns):
            sp = spearmanr(df[r], df[c])
            correlations[c][r] = sp[0]
            pvalues[c][r] = sp[1] if ix > jx else np.nan  # Only store values below the diagonal
    return correlations.astype("float"), pvalues.astype("float")


correlations, uncorrected_p_values = get_correlations(df_correlation)

# Correct p-values for multiple testing and check significance (True if the corrected p-value < 0.05)
shape = uncorrected_p_values.values.shape
significant_matrix = multipletests(uncorrected_p_values.values.flatten())[0].reshape(
    shape
)

# Here we start plotting
g = sns.clustermap(correlations, cmap="vlag", vmin=-1, vmax=1)

# Here labels on the y-axis are rotated
for tick in g.ax_heatmap.get_yticklabels():
    tick.set_rotation(0)

# Here we add asterisks onto cells with signficant correlations
for i, ix in enumerate(g.dendrogram_row.reordered_ind):
    for j, jx in enumerate(g.dendrogram_row.reordered_ind):
        if i != j:
            text = g.ax_heatmap.text(
                j + 0.5,
                i + 0.5,
                "*" if significant_matrix[ix, jx] or significant_matrix[jx, ix] else "",
                ha="center",
                va="center",
                color="black",
            )
            text.set_fontsize(20)

# Save a high-res copy of the image to disk
plt.tight_layout()
plt.savefig("clustermap.png", dpi=200)

# %%
# Extract from .score files 
dataset = "homfam"
easel_dir = join("/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/",dataset,"evaluation/easel/")
easel = pd.DataFrame()
for easel_name in os.listdir(easel_dir):
    easel_file = os.path.join(easel_dir,easel_name)
    # Parse file
    if easel_file.endswith("INFO"):
        easel_df = pd.read_csv(easel_file,sep = ":", header = None).drop([0,1,9], axis = 0)
        easel_df[1] = easel_df[1].str.strip()
        easel_df = easel_df.set_index(0).T
        easel_df["name"] = easel_name.replace(".easel_INFO", "")
        easel = easel.append(easel_df, ignore_index=True)
# Out:
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# ...
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)
# /tmp/ipykernel_19039/3160288920.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   easel = easel.append(easel_df, ignore_index=True)

# %%
# Out:
# 0    Number of sequences Alignment length Total # residues Smallest Largest  \
# 0                   9105             5805          2738115       27     461
# 1                    508              160            31654       30      77
# 2                      5              374             1409      223     342
# 3                      5               58              235       43      49
# 4                     15               39              436       25      34
# ...                  ...              ...              ...      ...     ...
# 1406                 837             1481           202818       18     689
# 1407                   6              140              638       99     124
# 1408                 774              117            29622       23      54
# 1409                   7              163              750       85     150
# 1410                3262             8773           926870       20     460
#
# 0    Average length Average identity  \
# 0             300.7              14%
# 1              62.3              35%
# 2             281.8              25%
# 3              47.0              38%
# 4              29.1              33%
# ...             ...              ...
# 1406          242.3              18%
# 1407          106.3              36%
# 1408           38.3              55%
# 1409          107.1              19%
# 1410          284.1              15%
#
# 0                                                  name
# 0     blm.dynamic.50.dynamicX.100000000.tcoffee_msa....
# 1                toxin.regressive.50.FAMSA.FAMSA-medoid
# 2              Sulfotransfer-ref.progressive.FAMSA.MBED
# 3                seatoxin-ref.progressive.EXPRESSO.MBED
# 4                    zf-CCHH-ref.progressive.FAMSA.MBED
# ...                                                 ...
# 1406  trfl.dynamic.50.dynamicX.100000000.tcoffee_msa...
# 1407                 rvp-ref.progressive.PROBAPAIR.MBED
# 1408                     ChtBD.regressive.50.FAMSA.MBED
# 1409                DEATH-ref.progressive.3DCOFFEE.MBED
# 1410               asp.regressive.50.FAMSA.FAMSA-medoid
#
# [1411 rows x 8 columns]
