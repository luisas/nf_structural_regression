# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import glob 
import matplotlib.pyplot as plt
import matplotlib as mpl

sns.set_context("talk")
data_dir = "/home/luisasantus/Desktop/crg_cluster/projects/structural_regression/results/homfam/"

# load families summary
summary_homfam_exthomfam = pd.read_csv("/home/luisasantus/Desktop/crg_cluster/data/structural_regression/stats/01_summary_homfam_exthomfam.csv")
summary_homfam = summary_homfam_exthomfam[summary_homfam_exthomfam.dataset == "homfam"]
families = summary_homfam.drop(["subset", "file", "min_length", "max_length", "perc_ref_total", "dataset"], axis = 1)

# 1. PREP SCORES
def get_scores(score_files): 
    def parse_score(score_file): 
        return(pd.read_csv(score_file,sep = ";", header = None).drop(4, axis = 1))

    scores = pd.concat(list(map(parse_score, score_files)))
    scores = scores.iloc[:,0:4]
    scores.columns = ['name', 'sp', 'tc', 'column']
    #scores.name = scores.name.str.split(".", expand = True)[:-1]
    #scores[["family", "method", "bucket_size", "align_method", "tree_method"]] = scores.name.str.split(".", expand = True)
    #scores = scores.drop("method", axis = 1)
    return(scores)

# %%
# Now check on few families, with N=100, famsa, mafft-ginsi 
fams = ["hip", "cryst", "seatoxin", "blmb", "DEATH", "sdr"]
methods = ["MAFFT-GINSI", "FAMSA"]
bucket_size = "100"
cols = ["family", "sp", "method", "n_sequences"]

# %%
# REGRESSIVE FAMSA and MAFFT GINSI 
regressive_sequence = get_scores((glob.glob(os.path.join(data_dir, "evaluation/score/*.regressive.*.MBED*"))))
regressive_sequence[["family", "algo","bucket", "align_method" , "tree_method"]] = regressive_sequence.name.str.split(".", expand = True)
regressive_sequence = pd.merge(regressive_sequence, families, on = "family")
regressive_sequence = regressive_sequence[(regressive_sequence.family.isin(fams)) & (regressive_sequence.bucket == bucket_size) & (regressive_sequence.align_method.isin(methods))]
regressive_sequence["method"] = regressive_sequence.algo + "_" + regressive_sequence["align_method"]

# %%
# REGRESSIVE FOLDSEEK 
tc_fs = get_scores(glob.glob(os.path.join(data_dir, "evaluation/score/*foldeek_regressive*")))
tc_fs[["family", "algo", "bucketsize","method", "tree_method"]] = tc_fs.name.str.split(".", expand = True)
tc_fs = pd.merge(tc_fs, families, on = "family")

# %%
# To check later --> DYNAMIC 
dynamic = get_scores((glob.glob(os.path.join(data_dir, "evaluation/score/*dynamic.*.MBED*"))))
dynamic[["family", "method", "a", "a", "a", "bucket", "tree_method","library_method"]] = dynamic.name.str.split(".", expand = True)
dynamic = pd.merge(dynamic, families, on = "family")
dynamic = dynamic[(dynamic.family.isin(fams))]

# %%
# COLLECT ALL SCORES 
scores = pd.concat([regressive_sequence[cols],dynamic[cols],tc_fs[cols] ])

# %%
# VISUALIZE 

import itertools
sns.set_theme(style="whitegrid")
sns.set_context("talk")

sorting_method = "regressive_MAFFT-GINSI"

sorter = scores[scores.method == sorting_method].sort_values("sp").family.to_frame()
scores = pd.merge(sorter,scores, on = "family", how = 'left')

# Create an array with the colors you want to use
colors = list(itertools.chain.from_iterable([["red", "blue", "grey", "black", "grey", "grey"],["orange"]*100]))

# colors = ["red", "blue", "grey", "black", "grey", "grey", rep(c("orag"))]
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))


g = sns.PairGrid(scores,
                 x_vars="sp", y_vars=["family"], hue = "method",
                 height=20, aspect=1)

# Draw a dot plot using the stripplot function
g.map(sns.stripplot, size=20, orient="h", jitter=False,
       linewidth=1, edgecolor="w")


for ax in g.axes.flat:
    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)

sns.despine(left=True, bottom=True)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = "method")

# %%
# T_COFFEE REGRESSIVE, STRUCTURE HYBRID IS BETTER THEN ALL - REG PROBA TCOFFEE, REG MAFFT SPARSECORE, FAMSA

# %%
# FAMSA
famsa = get_scores((glob.glob(os.path.join(data_dir, "evaluation/score/*progressive.*FAMSA.MBED*"))))
famsa[["family", "method", "tree_method","library_method"]] = famsa.name.str.split(".", expand = True)
famsa = pd.merge(famsa, families, on = "family")

# MAFFT
mafft = get_scores((glob.glob(os.path.join(data_dir, "evaluation/score/*regressive.*MAFFT-GINSI.*"))))
mafft[["family", "method", "bucketsize","tree_method","library_method"]] = mafft.name.str.split(".", expand = True)
mafft = pd.merge(mafft, families, on = "family")

#TCOFFEE FOLDSEEK 
tc_fs = get_scores(glob.glob(os.path.join(data_dir, "evaluation/score/*fs_regressive*")))
tc_fs[["family", "method", "bucketsize","library_method", "tree_method"]] = tc_fs.name.str.split(".", expand = True)
tc_fs = pd.merge(tc_fs, families, on = "family")

#TCOFFEE PROBA
#tc_proba = get_scores(glob.glob(os.path.join(data_dir, "evaluation/score/*fs_regressive*")))
#tc_proba[["family", "method", "bucketsize","library_method", "tree_method"]] = tc_proba.name.str.split(".", expand = True)
#tc_proba = pd.merge(tc_proba, families, on = "family")

# %% [markdown]
# 1 - On cryst diving into buckets and famsa mess up
#     - we take the 100
# 2 - Check how it does with foldseek, proba and fsproba
# 3 - Check how it does with real structures
#     3a- Dynamic
#     3b- Regressive + 3D project

# %%
# CRYST BEHAVIOUR 
famsa[famsa.family == "hip"]
# Out:
#                           name    sp    tc  column family       method  \
# 19  hip.progressive.FAMSA.MBED  88.7  71.4    77.3    hip  progressive
#
#    tree_method library_method  n_sequences  mean_length size_group
# 19       FAMSA           MBED          167    66.209581      small

# %%
mafft[mafft.family == "hip"]
# Out:
#                                              name    sp    tc  column family  \
# 0    hip.regressive.1000.MAFFT-GINSI.FAMSA-medoid  88.4  67.9    76.7    hip
# 1            hip.regressive.1000.MAFFT-GINSI.MBED  88.4  67.9    76.7    hip
# 2  hip.regressive.1000.MAFFT-GINSI.FAMSA-parttree  88.4  67.9    76.7    hip
# 3             hip.regressive.100.MAFFT-GINSI.MBED  85.5  61.9    71.8    hip
# 4     hip.regressive.100.MAFFT-GINSI.FAMSA-medoid  88.2  66.7    76.6    hip
# 5   hip.regressive.100.MAFFT-GINSI.FAMSA-parttree  88.8  69.0    77.6    hip
#
#        method bucketsize  tree_method  library_method  n_sequences  \
# 0  regressive       1000  MAFFT-GINSI    FAMSA-medoid          167
# 1  regressive       1000  MAFFT-GINSI            MBED          167
# 2  regressive       1000  MAFFT-GINSI  FAMSA-parttree          167
# 3  regressive        100  MAFFT-GINSI            MBED          167
# 4  regressive        100  MAFFT-GINSI    FAMSA-medoid          167
# 5  regressive        100  MAFFT-GINSI  FAMSA-parttree          167
#
#    mean_length size_group
# 0    66.209581      small
# 1    66.209581      small
# 2    66.209581      small
# 3    66.209581      small
# 4    66.209581      small
# 5    66.209581      small

# %%
tc_fs = get_scores(glob.glob(os.path.join(data_dir, "evaluation/score/*fs_regressive*")))

# %%
tc_fs
# Out:
#                                          name    sp    tc  column
# 0         hip.fs_regressive.1000.fsproba.MBED  78.5  51.2    62.2
# 0          hip.fs_regressive.100.fsproba.MBED  82.6  53.6    65.3
# 0        cryst.fs_regressive.100.fsproba.MBED  39.6   0.0     0.0
# 0          ghf11.fs_regressive.50.fsonly.MBED  85.2  67.7    71.7
# 0  seatoxin-ref.fs_regressive.50.fsproba.MBED  81.7  53.1    53.0
# 0            hip.fs_regressive.50.fsonly.MBED  80.8  54.8    63.6
# 0    seatoxin.fs_regressive.50.probaonly.MBED  69.2  20.4    21.3

# %%
#TCOFFEE FOLDSEEK 
tc_fs = get_scores(glob.glob(os.path.join(data_dir, "evaluation/score/*regressive*3*")))

# %%
tc_fs["family"] = tc_fs.name.str.split(".", expand = True)[0]

# %%
tc_fs[tc_fs.family == "cryst"]
# Out:
#                                               name    sp   tc  column family
# 0   cryst.regressive_comp_analysis.300.expand.MBED  58.1  1.7     0.8  cryst
# 0               cryst.regressive.100.3dcoffee.MBED  40.2  0.0     0.0  cryst
# 0  cryst.regressive_comp_analysis.300.compact.MBED  58.1  1.7     0.8  cryst

# %%
tc_fs[["family", "method", "bucketsize","library_method", "tree_method"]] = tc_fs.name.str.split(".", expand = True)
tc_fs = pd.merge(tc_fs, families, on = "family")

# %%
tm = get_scores(glob.glob(os.path.join(data_dir, "evaluation/score/*tmalign_only*")))
tm[["family", "method", "tree_method","library_method"]] = tm.name.str.split(".", expand = True)

# %%
tm[~tm.family.str.contains("-ref")]
# Out:
#                                   name    sp    tc  column    family  \
# 0  seatoxin.foldseek.MBED.tmalign_only  81.9  57.1    56.5  seatoxin
# 0       hip.foldseek.MBED.tmalign_only  91.2  71.4    78.2       hip
#
#      method tree_method library_method
# 0  foldseek        MBED   tmalign_only
# 0  foldseek        MBED   tmalign_only
